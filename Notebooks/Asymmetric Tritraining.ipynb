# %% [markdown]
# Mounting Google Drive and setting approapriate version of tensorflow

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 1.15.2

# %%
pip install nervaluate
# Out:
# Collecting nervaluate
#   Downloading nervaluate-0.1.8-py3-none-any.whl (24 kB)
# Installing collected packages: nervaluate
# Successfully installed nervaluate-0.1.8

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import numpy as np
from tensorflow.contrib.crf import crf_log_likelihood, crf_decode
from tensorflow.contrib.rnn import LSTMCell, GRUCell, BasicRNNCell
from sklearn.metrics import f1_score, precision_score, recall_score
from nervaluate import Evaluator
import sys
import random
import time
import pickle

# %%
class lstm_crf(object):

    '''
    lstm-crf for ner tagging
    
    parameters:
      - embedding_matrix: numpy array[float]
        numpy array of word embeddings
        each row should represent a word embedding
        NOTE: the word index 0 is dropped, so the first row is ignored
      - num_classes: int
        number of output classes
      - max_len: int (default: 50)
        maximum number of input tokens in any sequence
      - rnn_size: int (default: 300)
        number of rnn units in RNN layer
      - dropout_keep: float (default: 0.9)
        dropout keep rate after rnn layer
      - lr: float (default: 1E-4)
        learning rate for adam optimizer
       
    methods:
      - train(X,y,doc_lens,batch_size=128,epochs=25,patience=10,
              validation_data=None,savebest=False,filepath=None)
        train network on given data
      - predict(X,doc_lens,batch_size=128)
        return the predicted labels, flattened labels ignoring padding tokens, 
        and confidence scores for given data
      - score(X,y,doc_lens,batch_size=128)
        return the entity-level exact F1 score for given input sequences
      - save(filepath)
        save the model weights to a file
      - load(filepath)
        load model weights from a file
    '''

    def __init__(self,embedding_matrix,num_classes,max_len=50,rnn_size=300,dropout_keep=0.9,learning_rate=1E-4):
    
        #model params
        self.num_classes = num_classes
        self.embeddings = embedding_matrix.astype(np.float32)
        self.max_len = max_len
        self.rnn_size = rnn_size
        self.dropout_keep = dropout_keep
        self.idx2label = {0:'O',1:'B-ENT',2:'I-ENT'}
        self.lr = learning_rate
        
        #model inputs
        self.doc_inputs = tf.placeholder(tf.float32,shape=[None,max_len,200])
        self.doc_lens = tf.placeholder(tf.int32,shape=[None])
        self.labels = tf.placeholder(tf.int32,shape=[None,max_len])
        self.doc_idx = tf.placeholder(tf.int32,shape=[None,2])
        self.dropout = tf.placeholder(tf.float32)
        rnn_input = tf.nn.dropout(self.doc_inputs,self.dropout)
                      
        #bi-lstm
        with tf.variable_scope('rnn',initializer=tf.contrib.layers.xavier_initializer()):
            [outputs_fw,outputs_bw],_ = tf.nn.bidirectional_dynamic_rnn(
                            LSTMCell(self.rnn_size/2),LSTMCell(self.rnn_size/2),
                            rnn_input,sequence_length=self.doc_lens,dtype=tf.float32)
            outputs = tf.concat((outputs_fw,outputs_bw),2)
            outputs = tf.nn.dropout(outputs,self.dropout)
        
        #linear chain conditional random field
        unary_scores = tf.layers.dense(outputs,self.num_classes,
                       kernel_initializer=tf.contrib.layers.xavier_initializer())
        log_likelihood, self.transition_params = \
                       crf_log_likelihood(unary_scores,self.labels,self.doc_lens)
        self.pred, viterbi_score = crf_decode(unary_scores,self.transition_params,self.doc_lens)
        self.pred_flat = tf.gather_nd(self.pred,self.doc_idx)
        seq_score,_ = crf_log_likelihood(unary_scores,self.pred,self.doc_lens,
                                         self.transition_params)
        self.seq_score = seq_score/tf.cast(self.doc_lens,tf.float32)

        #loss, accuracy, and training functions
        self.loss = tf.reduce_mean(-log_likelihood)
        self.optimizer = tf.train.AdamOptimizer(self.lr,0.9,0.99).minimize(self.loss)
        
        #init ops
        config = tf.ConfigProto()
        config.gpu_options.allow_growth = True
        self.saver = tf.train.Saver()
        self.sess = tf.Session(config=config)
        self.sess.run(tf.global_variables_initializer())

    def _gen_doc_idx(self,doc_lens):
    
        doc_idx = []
        for i,l in enumerate(doc_lens):
            for j in range(l):
                doc_idx.append([i,j])
        doc_idx = np.array(doc_idx)

        return doc_idx
        
    def _flatten_y(self,y,doc_lens):
    
        y_flattened = []
        for i,(doc,l) in enumerate(zip(y,doc_lens)):       
            y_flattened.extend(doc[:l])
            
        return y_flattened
                    
    def train(self,X,y,doc_lens,batch_size=128,epochs=500,patience=20,
              validation_data=None,savebest=False,filepath=None):
    
        '''
        train network on given data
        
        parameters:
          - X: numpy array[int]
            2d numpy array (doc x word ids) of input data
          - y: numpy array[int]
            2d numpy array (doc x ner labels) of labels for given data
          - doc_lens: list[int]
            true sequence length of each sample
          - batch size: int (default: 128)
            batch size to use for training
          - epochs: int (default: 500)
            number of epochs to train for
          - patience: int (default: 10)
            training stops after no improvement in validation score
            for this number of epochs
          - validation_data: tuple (optional)
            tuple of numpy arrays (X,y) representing validation data
          - savebest: boolean (default: False)
            set to True to save the best model based on validation score per epoch
          - filepath: string (optional)
            path to save model if savebest is set to True
        
        outputs:
            None
        '''
    
        if savebest==True and filepath==None:
            raise Exception("Please enter a path to save the network")

        if validation_data:
            validation_size = len(validation_data[0])
        else:
            validation_size = len(X)

        print('training network on %i documents, validation on %i documents' \
              % (len(X), validation_size))

        #track best model for saving
        prevbest = 0
        pat_count = 0

        for ep in range(epochs):

            #shuffle data
            xyz = list(zip(X,y,doc_lens))            
            random.shuffle(xyz)
            X,y,doc_lens = zip(*xyz)
            X = list(X)
            y = list(y)
            doc_lens = list(doc_lens)

            y_pred = []
            y_true = []
            start_time = time.time()

            #train
            for start in range(0,len(X),batch_size):

                #get batch index
                if start+batch_size < len(X):
                    stop = start+batch_size
                else:
                    stop = len(X)

                embeds = np.take(self.embeddings,X[start:stop],0)
                feed_dict = {self.doc_inputs:embeds,
                             self.labels:y[start:stop],
                             self.doc_lens:doc_lens[start:stop],
                             self.doc_idx:self._gen_doc_idx(doc_lens[start:stop]),
                             self.dropout:self.dropout_keep}
                preds,loss,_ = self.sess.run([self.pred,self.loss,self.optimizer],
                              feed_dict=feed_dict)

                #track correct predictions
                for y_pred_,y_true_,l in zip(preds,y[start:stop],doc_lens[start:stop]):
                    y_p = [self.idx2label[l] for l in y_pred_[:l]]
                    y_t = [self.idx2label[l] for l in y_true_[:l]]
                    y_pred.append(y_p)
                    y_true.append(y_t)
                    
                sys.stdout.write("epoch %i, sample %i of %i, loss: %f        \r"\
                                 % (ep+1,stop,len(X),loss))
                sys.stdout.flush()

            #checkpoint after every epoch
            print("\ntraining time: %.2f" % (time.time()-start_time))
            evaluator = Evaluator(y_true, y_pred, tags=['ENT'], loader="list")
            results, results_by_tag = evaluator.evaluate()
            f1 = results['exact']['f1']
            print("epoch %i training f1: %.4f" % (ep+1,f1))

            f1 = self.score(validation_data[0],validation_data[1],
                            validation_data[2],batch_size=batch_size)
            print("epoch %i validation f1: %.4f" % (ep+1,f1))

            #save if performance better than previous best
            if f1 >= prevbest:
                prevbest = f1
                pat_count = 0
                if savebest:
                    self.save(filepath)
            else:
                pat_count += 1
                if pat_count >= patience:
                    break

            #reset timer
            start_time = time.time()

    def predict(self,X,doc_lens,batch_size=128):
    
        '''
        return the predicted labels, flattened labels ignoring padding tokens, 
        and confidence scores for given data
        
        parameters:
          - X: numpy array[int]
            2d numpy array (doc x word ids) of input data
          - doc_lens: list[int]
            true sequence length of each sample
          - batch size: int (default: 128)
            batch size to use for inference
            
        outputs:
          - y_pred: numpy_array[int]
            2d numpy array of predicted labels for input data
          - y_pred_flat: list[int]
            flattened list of all predicted labels ignoring padding tokens
          - scores: numpy_array[float]
            flattened list of confidence scores for all predicted labels ignoring padding tokens
        '''
    
        y_pred_flat = []
        y_pred = []
        scores = []
        
        for start in range(0,len(X),batch_size):

            #get batch index
            if start+batch_size < len(X):
                stop = start+batch_size
            else:
                stop = len(X)

            embeds = np.take(self.embeddings,X[start:stop],0)
            feed_dict = {self.doc_inputs:embeds,
                         self.doc_lens:doc_lens[start:stop],
                         self.doc_idx:self._gen_doc_idx(doc_lens[start:stop]),
                         self.dropout:1.0}
            pred,pred_flat,score = self.sess.run([self.pred,self.pred_flat,self.seq_score],
                                   feed_dict=feed_dict)

            score = np.exp(score)
            y_pred.append(pred)
            y_pred_flat.extend(pred_flat)
            scores.extend(score)

            sys.stdout.write("processed %i of %i records        \r" \
                             % (stop,len(X)))
            sys.stdout.flush()

        print()
        y_pred = np.vstack(y_pred)
        return y_pred,y_pred_flat,np.array(scores)

    def score(self,X,y,doc_lens,batch_size=128):
    
        '''
        return the entity-level exact F1 score for given input sequences
        
        parameters:
          - X: numpy array[int]
            2d numpy array (doc x word ids) of input data
          - y: numpy array[int]
            2d numpy array (doc x ner labels) of labels for given data
          - doc_lens: list[int]
            true sequence length of each sample
          - batch size: int (default: 128)
            batch size to use for inference
            
        outputs:
          - entity-level exact F1 score for given input sequences
        '''
        
        y_preds_,_,_ = self.predict(X,doc_lens,batch_size)
        y_pred = []
        y_true = []
        for y_pred_,y_true_,l in zip(y_preds_,y,doc_lens):
            y_p = [self.idx2label[l] for l in y_pred_[:l]]
            y_t = [self.idx2label[l] for l in y_true_[:l]]
            y_pred.append(y_p)
            y_true.append(y_t)
        
        evaluator = Evaluator(y_true, y_pred, tags=['ENT'], loader="list")
        results, results_by_tag = evaluator.evaluate()
        f1 = results['exact']['f1']
        
        return f1

    def save(self,filename):
    
        '''
        save the model weights to a file
        
        parameters:
          - filepath: string
            path to save model weights
        
        outputs:
            None
        '''
        
        self.saver.save(self.sess,filename)

    def load(self,filename):
    
        '''
        load model weights from a file
        
        parameters:
          - filepath: string
            path from which to load model weights
        
        outputs:
            None
        '''
        
        self.saver.restore(self.sess,filename)

# %%
class tt_bilstm_crf(object):

    '''
    lstm-crf for ner tagging
    
    parameters:
      - embedding_matrix: numpy array[float]
        numpy array of word embeddings
        each row should represent a word embedding
        NOTE: the word index 0 is dropped, so the first row is ignored
      - num_classes: int
        number of output classes
      - max_len: int (default: 50)
        maximum number of input tokens in any sequence
      - rnn_size: int (default: 300)
        number of rnn units in RNN layer
      - dropout_keep: float (default: 0.9)
        dropout keep rate after rnn layer
      - lr: float (default: 1E-4)
        learning rate for adam optimizer
       
    methods:
      - train(X,y,doc_lens,batch_size=128,epochs=25,patience=10,
              validation_data=None,savebest=False,filepath=None)
        train network on given data
      - predict(X,doc_lens,batch_size=128)
        return the predicted labels, flattened labels ignoring padding tokens, 
        and confidence scores for given data
      - score(X,y,doc_lens,batch_size=128)
        return the entity-level exact F1 score for given input sequences
      - save(filepath)
        save the model weights to a file
      - load(filepath)
        load model weights from a file
    '''

    def __init__(self,embedding_matrix,num_classes,max_len=50,rnn_size=300,dropout_keep=0.9,learning_rate=1E-4):
    
        #model params
        self.num_classes = num_classes
        self.embeddings = embedding_matrix.astype(np.float32)
        self.max_len = max_len
        self.rnn_size = rnn_size
        self.dropout_keep = dropout_keep
        self.idx2label = {0:'O',1:'B-ENT',2:'I-ENT'}
        self.lr = learning_rate
        
        #model inputs
        self.doc_inputs = tf.placeholder(tf.float32,shape=[None,max_len,200])
        self.doc_lens = tf.placeholder(tf.int32,shape=[None])
        self.labels = tf.placeholder(tf.int32,shape=[None,max_len])
        self.doc_idx = tf.placeholder(tf.int32,shape=[None,2])
        self.dropout = tf.placeholder(tf.float32)
        rnn_input = tf.nn.dropout(self.doc_inputs,self.dropout)
                      
        #bi-lstm
        with tf.variable_scope('rnn',initializer=tf.contrib.layers.xavier_initializer()):
            [outputs_fw,outputs_bw],_ = tf.nn.bidirectional_dynamic_rnn(
                            LSTMCell(self.rnn_size/2),LSTMCell(self.rnn_size/2),
                            rnn_input,sequence_length=self.doc_lens,dtype=tf.float32)
            outputs = tf.concat((outputs_fw,outputs_bw),2)
            outputs = tf.nn.dropout(outputs,self.dropout)
        
        #linear chain conditional random field
        unary_scores = tf.layers.dense(outputs,self.num_classes,
                       kernel_initializer=tf.contrib.layers.xavier_initializer())
        log_likelihood, self.transition_params = \
                       crf_log_likelihood(unary_scores,self.labels,self.doc_lens)
        self.pred, viterbi_score = crf_decode(unary_scores,self.transition_params,self.doc_lens)
        self.pred_flat = tf.gather_nd(self.pred,self.doc_idx)
        seq_score,_ = crf_log_likelihood(unary_scores,self.pred,self.doc_lens,
                                         self.transition_params)
        self.seq_score = seq_score/tf.cast(self.doc_lens,tf.float32)

        #loss, accuracy, and training functions
        self.loss = tf.reduce_mean(-log_likelihood)
        self.optimizer = tf.train.AdamOptimizer(self.lr,0.9,0.99).minimize(self.loss)
        
        #init ops
        config = tf.ConfigProto()
        config.gpu_options.allow_growth = True
        self.saver = tf.train.Saver()
        self.sess = tf.Session(config=config)
        self.sess.run(tf.global_variables_initializer())

    def _gen_doc_idx(self,doc_lens):
    
        doc_idx = []
        for i,l in enumerate(doc_lens):
            for j in range(l):
                doc_idx.append([i,j])
        doc_idx = np.array(doc_idx)

        return doc_idx
        
    def _flatten_y(self,y,doc_lens):
    
        y_flattened = []
        for i,(doc,l) in enumerate(zip(y,doc_lens)):       
            y_flattened.extend(doc[:l])
            
        return y_flattened
                    
    def train(self,X,y,doc_lens,batch_size=128,epochs=500,patience=20,
              validation_data=None,savebest=False,filepath=None):
    
        '''
        train network on given data
        
        parameters:
          - X: numpy array[int]
            2d numpy array (doc x word ids) of input data
          - y: numpy array[int]
            2d numpy array (doc x ner labels) of labels for given data
          - doc_lens: list[int]
            true sequence length of each sample
          - batch size: int (default: 128)
            batch size to use for training
          - epochs: int (default: 500)
            number of epochs to train for
          - patience: int (default: 10)
            training stops after no improvement in validation score
            for this number of epochs
          - validation_data: tuple (optional)
            tuple of numpy arrays (X,y) representing validation data
          - savebest: boolean (default: False)
            set to True to save the best model based on validation score per epoch
          - filepath: string (optional)
            path to save model if savebest is set to True
        
        outputs:
            None
        '''
    
        if savebest==True and filepath==None:
            raise Exception("Please enter a path to save the network")

        if validation_data:
            validation_size = len(validation_data[0])
        else:
            validation_size = len(X)

        print('Entered BiLSTM-CRF. Training network on %i documents, validation on %i documents' \
              % (len(X), validation_size))

        #track best model for saving
        prevbest = 0
        pat_count = 0

        for ep in range(epochs):

            #shuffle data
            xyz = list(zip(X,y,doc_lens))            
            random.shuffle(xyz)
            X,y,doc_lens = zip(*xyz)
            X = list(X)
            y = list(y)
            doc_lens = list(doc_lens)

            y_pred = []
            y_true = []
            start_time = time.time()

            #train
            for start in range(0,len(X),batch_size):

                #get batch index
                if start+batch_size < len(X):
                    stop = start+batch_size
                else:
                    stop = len(X)

                embeds = np.take(self.embeddings,X[start:stop],0)
                feed_dict = {self.doc_inputs:embeds,
                             self.labels:y[start:stop],
                             self.doc_lens:doc_lens[start:stop],
                             self.doc_idx:self._gen_doc_idx(doc_lens[start:stop]),
                             self.dropout:self.dropout_keep}
                preds,loss,_ = self.sess.run([self.pred,self.loss,self.optimizer],
                              feed_dict=feed_dict)

                #track correct predictions
                for y_pred_,y_true_,l in zip(preds,y[start:stop],doc_lens[start:stop]):
                    y_p = [self.idx2label[l] for l in y_pred_[:l]]
                    y_t = [self.idx2label[l] for l in y_true_[:l]]
                    y_pred.append(y_p)
                    y_true.append(y_t)
                    
                sys.stdout.write("epoch %i, sample %i of %i, loss: %f        \r"\
                                 % (ep+1,stop,len(X),loss))
                sys.stdout.flush()

            #checkpoint after every epoch
            print("\ntraining time: %.2f" % (time.time()-start_time))
            evaluator = Evaluator(y_true, y_pred, tags=['ENT'], loader="list")
            results, results_by_tag = evaluator.evaluate()
            f1 = results['exact']['f1']
            print("epoch %i training f1: %.4f" % (ep+1,f1))

            f1 = self.score(validation_data[0],validation_data[1],
                            validation_data[2],batch_size=batch_size)
            print("epoch %i validation f1: %.4f" % (ep+1,f1))

            #save if performance better than previous best
            if f1 >= prevbest:
                prevbest = f1
                pat_count = 0
                if savebest:
                    self.save(filepath)
            else:
                pat_count += 1
                if pat_count >= patience:
                    break

            #reset timer
            start_time = time.time()

    def predict(self,X,doc_lens,batch_size=128):
    
        '''
        return the predicted labels, flattened labels ignoring padding tokens, 
        and confidence scores for given data
        
        parameters:
          - X: numpy array[int]
            2d numpy array (doc x word ids) of input data
          - doc_lens: list[int]
            true sequence length of each sample
          - batch size: int (default: 128)
            batch size to use for inference
            
        outputs:
          - y_pred: numpy_array[int]
            2d numpy array of predicted labels for input data
          - y_pred_flat: list[int]
            flattened list of all predicted labels ignoring padding tokens
          - scores: numpy_array[float]
            flattened list of confidence scores for all predicted labels ignoring padding tokens
        '''
    
        y_pred_flat = []
        y_pred = []
        scores = []
        
        for start in range(0,len(X),batch_size):

            #get batch index
            if start+batch_size < len(X):
                stop = start+batch_size
            else:
                stop = len(X)

            embeds = np.take(self.embeddings,X[start:stop],0)
            feed_dict = {self.doc_inputs:embeds,
                         self.doc_lens:doc_lens[start:stop],
                         self.doc_idx:self._gen_doc_idx(doc_lens[start:stop]),
                         self.dropout:1.0}
            pred,pred_flat,score = self.sess.run([self.pred,self.pred_flat,self.seq_score],
                                   feed_dict=feed_dict)

            score = np.exp(score)
            y_pred.append(pred)
            y_pred_flat.extend(pred_flat)
            scores.extend(score)

            sys.stdout.write("processed %i of %i records        \r" \
                             % (stop,len(X)))
            sys.stdout.flush()

        print()
        y_pred = np.vstack(y_pred)
        return y_pred,y_pred_flat,np.array(scores)

    def score(self,X,y,doc_lens,batch_size=128):
    
        '''
        return the entity-level exact F1 score for given input sequences
        
        parameters:
          - X: numpy array[int]
            2d numpy array (doc x word ids) of input data
          - y: numpy array[int]
            2d numpy array (doc x ner labels) of labels for given data
          - doc_lens: list[int]
            true sequence length of each sample
          - batch size: int (default: 128)
            batch size to use for inference
            
        outputs:
          - entity-level exact F1 score for given input sequences
        '''
        
        y_preds_,_,_ = self.predict(X,doc_lens,batch_size)
        y_pred = []
        y_true = []
        for y_pred_,y_true_,l in zip(y_preds_,y,doc_lens):
            y_p = [self.idx2label[l] for l in y_pred_[:l]]
            y_t = [self.idx2label[l] for l in y_true_[:l]]
            y_pred.append(y_p)
            y_true.append(y_t)
        
        evaluator = Evaluator(y_true, y_pred, tags=['ENT'], loader="list")
        results, results_by_tag = evaluator.evaluate()
        f1 = results['exact']['f1']
        
        return f1

    def save(self,filename):
    
        '''
        save the model weights to a file
        
        parameters:
          - filepath: string
            path to save model weights
        
        outputs:
            None
        '''
        
        self.saver.save(self.sess,filename)

    def load(self,filename):
    
        '''
        load model weights from a file
        
        parameters:
          - filepath: string
            path from which to load model weights
        
        outputs:
            None
        '''
        
        self.saver.restore(self.sess,filename)

# %%
class tt_birnn_crf(object):

    '''
    birnn-crf for ner tagging
    
    parameters:
      - embedding_matrix: numpy array[float]
        numpy array of word embeddings
        each row should represent a word embedding
        NOTE: the word index 0 is dropped, so the first row is ignored
      - num_classes: int
        number of output classes
      - max_len: int (default: 50)
        maximum number of input tokens in any sequence
      - rnn_size: int (default: 300)
        number of rnn units in RNN layer
      - dropout_keep: float (default: 0.9)
        dropout keep rate after rnn layer
      - lr: float (default: 1E-4)
        learning rate for adam optimizer
       
    methods:
      - train(X,y,doc_lens,batch_size=128,epochs=25,patience=10,
              validation_data=None,savebest=False,filepath=None)
        train network on given data
      - predict(X,doc_lens,batch_size=128)
        return the predicted labels, flattened labels ignoring padding tokens, 
        and confidence scores for given data
      - score(X,y,doc_lens,batch_size=128)
        return the entity-level exact F1 score for given input sequences
      - save(filepath)
        save the model weights to a file
      - load(filepath)
        load model weights from a file
    '''

    def __init__(self,embedding_matrix,num_classes,max_len=50,rnn_size=300,dropout_keep=0.9,learning_rate=1E-4):
    
        #model params
        self.num_classes = num_classes
        self.embeddings = embedding_matrix.astype(np.float32)
        self.max_len = max_len
        self.rnn_size = rnn_size
        self.dropout_keep = dropout_keep
        self.idx2label = {0:'O',1:'B-ENT',2:'I-ENT'}
        self.lr = learning_rate
        
        #model inputs
        self.doc_inputs = tf.placeholder(tf.float32,shape=[None,max_len,200])
        self.doc_lens = tf.placeholder(tf.int32,shape=[None])
        self.labels = tf.placeholder(tf.int32,shape=[None,max_len])
        self.doc_idx = tf.placeholder(tf.int32,shape=[None,2])
        self.dropout = tf.placeholder(tf.float32)
        rnn_input = tf.nn.dropout(self.doc_inputs,self.dropout)

        #bi-rnn              
        with tf.variable_scope('rnn',initializer=tf.contrib.layers.xavier_initializer()):
            [outputs_fw,outputs_bw],_ = tf.nn.bidirectional_dynamic_rnn(
                            BasicRNNCell(self.rnn_size/2),BasicRNNCell(self.rnn_size/2),
                            rnn_input,sequence_length=self.doc_lens,dtype=tf.float32)
            outputs = tf.concat((outputs_fw,outputs_bw),2)
            outputs = tf.nn.dropout(outputs,self.dropout)
        
        #linear chain conditional random field
        unary_scores = tf.layers.dense(outputs,self.num_classes,
                       kernel_initializer=tf.contrib.layers.xavier_initializer())
        log_likelihood, self.transition_params = \
                       crf_log_likelihood(unary_scores,self.labels,self.doc_lens)
        self.pred, viterbi_score = crf_decode(unary_scores,self.transition_params,self.doc_lens)
        self.pred_flat = tf.gather_nd(self.pred,self.doc_idx)
        seq_score,_ = crf_log_likelihood(unary_scores,self.pred,self.doc_lens,
                                         self.transition_params)
        self.seq_score = seq_score/tf.cast(self.doc_lens,tf.float32)

        #loss, accuracy, and training functions
        self.loss = tf.reduce_mean(-log_likelihood)
        self.optimizer = tf.train.AdamOptimizer(self.lr,0.9,0.99).minimize(self.loss)
        
        #init ops
        config = tf.ConfigProto()
        config.gpu_options.allow_growth = True
        self.saver = tf.train.Saver()
        self.sess = tf.Session(config=config)
        self.sess.run(tf.global_variables_initializer())

    def _gen_doc_idx(self,doc_lens):
    
        doc_idx = []
        for i,l in enumerate(doc_lens):
            for j in range(l):
                doc_idx.append([i,j])
        doc_idx = np.array(doc_idx)

        return doc_idx
        
    def _flatten_y(self,y,doc_lens):
    
        y_flattened = []
        for i,(doc,l) in enumerate(zip(y,doc_lens)):       
            y_flattened.extend(doc[:l])
            
        return y_flattened
                    
    def train(self,X,y,doc_lens,batch_size=128,epochs=500,patience=20,
              validation_data=None,savebest=False,filepath=None):
    
        '''
        train network on given data
        
        parameters:
          - X: numpy array[int]
            2d numpy array (doc x word ids) of input data
          - y: numpy array[int]
            2d numpy array (doc x ner labels) of labels for given data
          - doc_lens: list[int]
            true sequence length of each sample
          - batch size: int (default: 128)
            batch size to use for training
          - epochs: int (default: 500)
            number of epochs to train for
          - patience: int (default: 10)
            training stops after no improvement in validation score
            for this number of epochs
          - validation_data: tuple (optional)
            tuple of numpy arrays (X,y) representing validation data
          - savebest: boolean (default: False)
            set to True to save the best model based on validation score per epoch
          - filepath: string (optional)
            path to save model if savebest is set to True
        
        outputs:
            None
        '''
    
        if savebest==True and filepath==None:
            raise Exception("Please enter a path to save the network")

        if validation_data:
            validation_size = len(validation_data[0])
        else:
            validation_size = len(X)

        print('Entered BiRNN-CRF. Training network on %i documents, validation on %i documents' \
              % (len(X), validation_size))

        #track best model for saving
        prevbest = 0
        pat_count = 0

        for ep in range(epochs):

            #shuffle data
            xyz = list(zip(X,y,doc_lens))            
            random.shuffle(xyz)
            X,y,doc_lens = zip(*xyz)
            X = list(X)
            y = list(y)
            doc_lens = list(doc_lens)

            y_pred = []
            y_true = []
            start_time = time.time()

            #train
            for start in range(0,len(X),batch_size):

                #get batch index
                if start+batch_size < len(X):
                    stop = start+batch_size
                else:
                    stop = len(X)

                embeds = np.take(self.embeddings,X[start:stop],0)
                feed_dict = {self.doc_inputs:embeds,
                             self.labels:y[start:stop],
                             self.doc_lens:doc_lens[start:stop],
                             self.doc_idx:self._gen_doc_idx(doc_lens[start:stop]),
                             self.dropout:self.dropout_keep}
                preds,loss,_ = self.sess.run([self.pred,self.loss,self.optimizer],
                              feed_dict=feed_dict)

                #track correct predictions
                for y_pred_,y_true_,l in zip(preds,y[start:stop],doc_lens[start:stop]):
                    y_p = [self.idx2label[l] for l in y_pred_[:l]]
                    y_t = [self.idx2label[l] for l in y_true_[:l]]
                    y_pred.append(y_p)
                    y_true.append(y_t)
                    
                sys.stdout.write("epoch %i, sample %i of %i, loss: %f        \r"\
                                 % (ep+1,stop,len(X),loss))
                sys.stdout.flush()

            #checkpoint after every epoch
            print("\ntraining time: %.2f" % (time.time()-start_time))
            evaluator = Evaluator(y_true, y_pred, tags=['ENT'], loader="list")
            results, results_by_tag = evaluator.evaluate()
            f1 = results['exact']['f1']
            print("epoch %i training f1: %.4f" % (ep+1,f1))

            f1 = self.score(validation_data[0],validation_data[1],
                            validation_data[2],batch_size=batch_size)
            print("epoch %i validation f1: %.4f" % (ep+1,f1))

            #save if performance better than previous best
            if f1 >= prevbest:
                prevbest = f1
                pat_count = 0
                if savebest:
                    self.save(filepath)
            else:
                pat_count += 1
                if pat_count >= patience:
                    break

            #reset timer
            start_time = time.time()

    def predict(self,X,doc_lens,batch_size=128):
    
        '''
        return the predicted labels, flattened labels ignoring padding tokens, 
        and confidence scores for given data
        
        parameters:
          - X: numpy array[int]
            2d numpy array (doc x word ids) of input data
          - doc_lens: list[int]
            true sequence length of each sample
          - batch size: int (default: 128)
            batch size to use for inference
            
        outputs:
          - y_pred: numpy_array[int]
            2d numpy array of predicted labels for input data
          - y_pred_flat: list[int]
            flattened list of all predicted labels ignoring padding tokens
          - scores: numpy_array[float]
            flattened list of confidence scores for all predicted labels ignoring padding tokens
        '''
    
        y_pred_flat = []
        y_pred = []
        scores = []
        
        for start in range(0,len(X),batch_size):

            #get batch index
            if start+batch_size < len(X):
                stop = start+batch_size
            else:
                stop = len(X)

            embeds = np.take(self.embeddings,X[start:stop],0)
            feed_dict = {self.doc_inputs:embeds,
                         self.doc_lens:doc_lens[start:stop],
                         self.doc_idx:self._gen_doc_idx(doc_lens[start:stop]),
                         self.dropout:1.0}
            pred,pred_flat,score = self.sess.run([self.pred,self.pred_flat,self.seq_score],
                                   feed_dict=feed_dict)

            score = np.exp(score)
            y_pred.append(pred)
            y_pred_flat.extend(pred_flat)
            scores.extend(score)

            sys.stdout.write("processed %i of %i records        \r" \
                             % (stop,len(X)))
            sys.stdout.flush()

        print()
        y_pred = np.vstack(y_pred)
        return y_pred,y_pred_flat,np.array(scores)

    def score(self,X,y,doc_lens,batch_size=128):
    
        '''
        return the entity-level exact F1 score for given input sequences
        
        parameters:
          - X: numpy array[int]
            2d numpy array (doc x word ids) of input data
          - y: numpy array[int]
            2d numpy array (doc x ner labels) of labels for given data
          - doc_lens: list[int]
            true sequence length of each sample
          - batch size: int (default: 128)
            batch size to use for inference
            
        outputs:
          - entity-level exact F1 score for given input sequences
        '''
        
        y_preds_,_,_ = self.predict(X,doc_lens,batch_size)
        y_pred = []
        y_true = []
        for y_pred_,y_true_,l in zip(y_preds_,y,doc_lens):
            y_p = [self.idx2label[l] for l in y_pred_[:l]]
            y_t = [self.idx2label[l] for l in y_true_[:l]]
            y_pred.append(y_p)
            y_true.append(y_t)
        
        evaluator = Evaluator(y_true, y_pred, tags=['ENT'], loader="list")
        results, results_by_tag = evaluator.evaluate()
        f1 = results['exact']['f1']
        
        return f1

    def save(self,filename):
    
        '''
        save the model weights to a file
        
        parameters:
          - filepath: string
            path to save model weights
        
        outputs:
            None
        '''
        
        self.saver.save(self.sess,filename)

    def load(self,filename):
    
        '''
        load model weights from a file
        
        parameters:
          - filepath: string
            path from which to load model weights
        
        outputs:
            None
        '''
        
        self.saver.restore(self.sess,filename)

# %%
class tt_bigru_crf(object):

    '''
    bigru-crf for ner tagging
    
    parameters:
      - embedding_matrix: numpy array[float]
        numpy array of word embeddings
        each row should represent a word embedding
        NOTE: the word index 0 is dropped, so the first row is ignored
      - num_classes: int
        number of output classes
      - max_len: int (default: 50)
        maximum number of input tokens in any sequence
      - rnn_size: int (default: 300)
        number of rnn units in RNN layer
      - dropout_keep: float (default: 0.9)
        dropout keep rate after rnn layer
      - lr: float (default: 1E-4)
        learning rate for adam optimizer
       
    methods:
      - train(X,y,doc_lens,batch_size=128,epochs=25,patience=10,
              validation_data=None,savebest=False,filepath=None)
        train network on given data
      - predict(X,doc_lens,batch_size=128)
        return the predicted labels, flattened labels ignoring padding tokens, 
        and confidence scores for given data
      - score(X,y,doc_lens,batch_size=128)
        return the entity-level exact F1 score for given input sequences
      - save(filepath)
        save the model weights to a file
      - load(filepath)
        load model weights from a file
    '''

    def __init__(self,embedding_matrix,num_classes,max_len=50,rnn_size=300,dropout_keep=0.9,learning_rate=1E-4):
    
        #model params
        self.num_classes = num_classes
        self.embeddings = embedding_matrix.astype(np.float32)
        self.max_len = max_len
        self.rnn_size = rnn_size
        self.dropout_keep = dropout_keep
        self.idx2label = {0:'O',1:'B-ENT',2:'I-ENT'}
        self.lr = learning_rate
        
        #model inputs
        self.doc_inputs = tf.placeholder(tf.float32,shape=[None,max_len,200])
        self.doc_lens = tf.placeholder(tf.int32,shape=[None])
        self.labels = tf.placeholder(tf.int32,shape=[None,max_len])
        self.doc_idx = tf.placeholder(tf.int32,shape=[None,2])
        self.dropout = tf.placeholder(tf.float32)
        rnn_input = tf.nn.dropout(self.doc_inputs,self.dropout)

        #bi-rnn              
        with tf.variable_scope('rnn',initializer=tf.contrib.layers.xavier_initializer()):
            with tf.variable_scope('forward'):        
              gru_fw_cell = tf.contrib.rnn.GRUCell(self.rnn_size/2)        
              gru_fw_cell = tf.contrib.rnn.DropoutWrapper(gru_fw_cell)    
            with tf.variable_scope('backward'):        
              gru_bw_cell = tf.contrib.rnn.GRUCell(self.rnn_size/2)        
              gru_bw_cell = tf.contrib.rnn.DropoutWrapper(gru_bw_cell)

            [outputs_fw,outputs_bw],_ = tf.nn.bidirectional_dynamic_rnn(
                            gru_fw_cell,gru_bw_cell,
                            rnn_input,sequence_length=self.doc_lens,dtype=tf.float32)
            outputs = tf.concat((outputs_fw,outputs_bw),2)
            outputs = tf.nn.dropout(outputs,self.dropout)
        
        #linear chain conditional random field
        unary_scores = tf.layers.dense(outputs,self.num_classes,
                       kernel_initializer=tf.contrib.layers.xavier_initializer())
        log_likelihood, self.transition_params = \
                       crf_log_likelihood(unary_scores,self.labels,self.doc_lens)
        self.pred, viterbi_score = crf_decode(unary_scores,self.transition_params,self.doc_lens)
        self.pred_flat = tf.gather_nd(self.pred,self.doc_idx)
        seq_score,_ = crf_log_likelihood(unary_scores,self.pred,self.doc_lens,
                                         self.transition_params)
        self.seq_score = seq_score/tf.cast(self.doc_lens,tf.float32)

        #loss, accuracy, and training functions
        self.loss = tf.reduce_mean(-log_likelihood)
        self.optimizer = tf.train.AdamOptimizer(self.lr,0.9,0.99).minimize(self.loss)
        
        #init ops
        config = tf.ConfigProto()
        config.gpu_options.allow_growth = True
        self.saver = tf.train.Saver()
        self.sess = tf.Session(config=config)
        self.sess.run(tf.global_variables_initializer())

    def _gen_doc_idx(self,doc_lens):
    
        doc_idx = []
        for i,l in enumerate(doc_lens):
            for j in range(l):
                doc_idx.append([i,j])
        doc_idx = np.array(doc_idx)

        return doc_idx
        
    def _flatten_y(self,y,doc_lens):
    
        y_flattened = []
        for i,(doc,l) in enumerate(zip(y,doc_lens)):       
            y_flattened.extend(doc[:l])
            
        return y_flattened
                    
    def train(self,X,y,doc_lens,batch_size=128,epochs=500,patience=20,
              validation_data=None,savebest=False,filepath=None):
    
        '''
        train network on given data
        
        parameters:
          - X: numpy array[int]
            2d numpy array (doc x word ids) of input data
          - y: numpy array[int]
            2d numpy array (doc x ner labels) of labels for given data
          - doc_lens: list[int]
            true sequence length of each sample
          - batch size: int (default: 128)
            batch size to use for training
          - epochs: int (default: 500)
            number of epochs to train for
          - patience: int (default: 10)
            training stops after no improvement in validation score
            for this number of epochs
          - validation_data: tuple (optional)
            tuple of numpy arrays (X,y) representing validation data
          - savebest: boolean (default: False)
            set to True to save the best model based on validation score per epoch
          - filepath: string (optional)
            path to save model if savebest is set to True
        
        outputs:
            None
        '''
    
        if savebest==True and filepath==None:
            raise Exception("Please enter a path to save the network")

        if validation_data:
            validation_size = len(validation_data[0])
        else:
            validation_size = len(X)

        print('Entered BiGRU-CRF. Training network on %i documents, validation on %i documents' \
              % (len(X), validation_size))

        #track best model for saving
        prevbest = 0
        pat_count = 0

        for ep in range(epochs):

            #shuffle data
            xyz = list(zip(X,y,doc_lens))            
            random.shuffle(xyz)
            X,y,doc_lens = zip(*xyz)
            X = list(X)
            y = list(y)
            doc_lens = list(doc_lens)

            y_pred = []
            y_true = []
            start_time = time.time()

            #train
            for start in range(0,len(X),batch_size):

                #get batch index
                if start+batch_size < len(X):
                    stop = start+batch_size
                else:
                    stop = len(X)

                embeds = np.take(self.embeddings,X[start:stop],0)
                feed_dict = {self.doc_inputs:embeds,
                             self.labels:y[start:stop],
                             self.doc_lens:doc_lens[start:stop],
                             self.doc_idx:self._gen_doc_idx(doc_lens[start:stop]),
                             self.dropout:self.dropout_keep}
                preds,loss,_ = self.sess.run([self.pred,self.loss,self.optimizer],
                              feed_dict=feed_dict)

                #track correct predictions
                for y_pred_,y_true_,l in zip(preds,y[start:stop],doc_lens[start:stop]):
                    y_p = [self.idx2label[l] for l in y_pred_[:l]]
                    y_t = [self.idx2label[l] for l in y_true_[:l]]
                    y_pred.append(y_p)
                    y_true.append(y_t)
                    
                sys.stdout.write("epoch %i, sample %i of %i, loss: %f        \r"\
                                 % (ep+1,stop,len(X),loss))
                sys.stdout.flush()

            #checkpoint after every epoch
            print("\ntraining time: %.2f" % (time.time()-start_time))
            evaluator = Evaluator(y_true, y_pred, tags=['ENT'], loader="list")
            results, results_by_tag = evaluator.evaluate()
            f1 = results['exact']['f1']
            print("epoch %i training f1: %.4f" % (ep+1,f1))

            f1 = self.score(validation_data[0],validation_data[1],
                            validation_data[2],batch_size=batch_size)
            print("epoch %i validation f1: %.4f" % (ep+1,f1))

            #save if performance better than previous best
            if f1 >= prevbest:
                prevbest = f1
                pat_count = 0
                if savebest:
                    self.save(filepath)
            else:
                pat_count += 1
                if pat_count >= patience:
                    break

            #reset timer
            start_time = time.time()

    def predict(self,X,doc_lens,batch_size=128):
    
        '''
        return the predicted labels, flattened labels ignoring padding tokens, 
        and confidence scores for given data
        
        parameters:
          - X: numpy array[int]
            2d numpy array (doc x word ids) of input data
          - doc_lens: list[int]
            true sequence length of each sample
          - batch size: int (default: 128)
            batch size to use for inference
            
        outputs:
          - y_pred: numpy_array[int]
            2d numpy array of predicted labels for input data
          - y_pred_flat: list[int]
            flattened list of all predicted labels ignoring padding tokens
          - scores: numpy_array[float]
            flattened list of confidence scores for all predicted labels ignoring padding tokens
        '''
    
        y_pred_flat = []
        y_pred = []
        scores = []
        
        for start in range(0,len(X),batch_size):

            #get batch index
            if start+batch_size < len(X):
                stop = start+batch_size
            else:
                stop = len(X)

            embeds = np.take(self.embeddings,X[start:stop],0)
            feed_dict = {self.doc_inputs:embeds,
                         self.doc_lens:doc_lens[start:stop],
                         self.doc_idx:self._gen_doc_idx(doc_lens[start:stop]),
                         self.dropout:1.0}
            pred,pred_flat,score = self.sess.run([self.pred,self.pred_flat,self.seq_score],
                                   feed_dict=feed_dict)

            score = np.exp(score)
            y_pred.append(pred)
            y_pred_flat.extend(pred_flat)
            scores.extend(score)

            sys.stdout.write("processed %i of %i records        \r" \
                             % (stop,len(X)))
            sys.stdout.flush()

        print()
        y_pred = np.vstack(y_pred)
        return y_pred,y_pred_flat,np.array(scores)

    def score(self,X,y,doc_lens,batch_size=128):
    
        '''
        return the entity-level exact F1 score for given input sequences
        
        parameters:
          - X: numpy array[int]
            2d numpy array (doc x word ids) of input data
          - y: numpy array[int]
            2d numpy array (doc x ner labels) of labels for given data
          - doc_lens: list[int]
            true sequence length of each sample
          - batch size: int (default: 128)
            batch size to use for inference
            
        outputs:
          - entity-level exact F1 score for given input sequences
        '''
        
        y_preds_,_,_ = self.predict(X,doc_lens,batch_size)
        y_pred = []
        y_true = []
        for y_pred_,y_true_,l in zip(y_preds_,y,doc_lens):
            y_p = [self.idx2label[l] for l in y_pred_[:l]]
            y_t = [self.idx2label[l] for l in y_true_[:l]]
            y_pred.append(y_p)
            y_true.append(y_t)
        
        evaluator = Evaluator(y_true, y_pred, tags=['ENT'], loader="list")
        results, results_by_tag = evaluator.evaluate()
        f1 = results['exact']['f1']
        
        return f1

    def save(self,filename):
    
        '''
        save the model weights to a file
        
        parameters:
          - filepath: string
            path to save model weights
        
        outputs:
            None
        '''
        
        self.saver.save(self.sess,filename)

    def load(self,filename):
    
        '''
        load model weights from a file
        
        parameters:
          - filepath: string
            path from which to load model weights
        
        outputs:
            None
        '''
        
        self.saver.restore(self.sess,filename)

# %%
# datasets to test on
datasets = [
            #'BC2GM',
            #'BC4CHEMD', 
            #'NCBI-disease',
            's800'
           ]

# supervised dataset sizes to test on
data_sizes = [
              2000
             ]

# %%
pretrain_dataset = 'medmentions'

# %%
batch_size_s = 128
patience_s = 15
holdout_confidence = 0.98

# %%
vocab = np.load('/content/drive/MyDrive/Pubmed/vocab.npy').astype(np.int16)

# %% [markdown]
# Asymmetric tri-training for aforementioned datasets of specified labeled training sizes

# %%
for dataset in datasets:

    # iterate over each data size setting
    for data_size in data_sizes:

        print('Training in the dataset loop',dataset,data_size)
        
        # load data
        X = np.load('/content/drive/MyDrive/Pubmed/%s_X_train.npy' % dataset).astype(np.int16)
        y = np.load('/content/drive/MyDrive/Pubmed/%s_y_train.npy' % dataset).astype(np.int16)
        max_len = 50
        num_classes = np.max(y) + 1
        
        with open('/content/drive/MyDrive/Pubmed/%s_senlens_train.pkl' % dataset,'rb') as f:
            doc_len = pickle.load(f)
        doc_len = [l if l <=max_len else max_len for l in doc_len]
        
        # load conversion dictionaries
        label2idx = {'O':0, 'B':1, 'I': 2}
        idx2label = {0:'O',1:'B-ENT',2:'I-ENT'}
            
        # train val split
        start_size = data_size
        train_size = int(0.8 * data_size)
        X_start = X[:start_size]
        y_start = y[:start_size]
        doc_len_start = np.array(doc_len[:start_size])
        X_holdout = X[start_size:]
        y_holdout = y[start_size:]
        doc_len_holdout = np.array(doc_len[start_size:])
        
        X_train = X_start[:train_size]
        X_val = X_start[train_size:]
        y_train = y_start[:train_size]
        y_val = y_start[train_size:]
        doc_len_train = np.array(doc_len_start[:train_size])
        doc_len_val = np.array(doc_len_start[train_size:])
        
        # load test data
        X_test = np.load('/content/drive/MyDrive/Pubmed/%s_X_test.npy' % dataset).astype(np.int16)
        y_test = np.load('/content/drive/MyDrive/Pubmed/%s_y_test.npy' % dataset).astype(np.int16)
        with open('/content/drive/MyDrive/Pubmed/%s_senlens_test.pkl' % dataset,'rb') as f:
            doc_len_test = pickle.load(f)
        doc_len_test = [l if l <=max_len else max_len for l in doc_len_test]
        y_true = []
        for y_true_,l in zip(y_test,doc_len_test):
            y = [idx2label[l] for l in y_true_[:l]]
            y_true.append(y)
        y_true_val = []
        for y_true_,l in zip(y_val,doc_len_val):
            y = [idx2label[l] for l in y_true_[:l]]
            y_true_val.append(y)
        

        i = 0
        training_sizes = []
        filter_size = np.inf
        
        # loop through holdout set until no new samples are added
        while filter_size > 0:
                                
            num_samples = len(X_train)
            training_sizes.append(num_samples)
            print('train size:',num_samples)
            
            # train model
            tf.reset_default_graph()
            model1 = tt_bilstm_crf(vocab, num_classes, max_len)
            tf.reset_default_graph()
            model2 = tt_birnn_crf(vocab, num_classes, max_len)
            tf.reset_default_graph()
            model3 = tt_bigru_crf(vocab, num_classes, max_len)
            
            
            model1.train(X_train,y_train,doc_len_train,
                        batch_size=batch_size_s,patience=patience_s,
                        validation_data=(X_val,y_val,doc_len_val),
                        savebest=True,filepath='/content/drive/MyDrive/Pubmed/SavedModels/%s_tt_lstm_crf_%i_%i.ckpt' % (dataset,train_size,i))
            
            model2.train(X_train,y_train,doc_len_train,
                        batch_size=batch_size_s,patience=patience_s,
                        validation_data=(X_val,y_val,doc_len_val),
                        savebest=True,filepath='/content/drive/MyDrive/Pubmed/SavedModels/%s_tt_rnn_crf_%i_%i.ckpt' % (dataset,train_size,i))
            
            
            # add high conf from holdout to test
            model1.load('/content/drive/MyDrive/Pubmed/SavedModels/%s_tt_lstm_crf_%i_%i.ckpt' % (dataset,train_size,i))
            model2.load('/content/drive/MyDrive/Pubmed/SavedModels/%s_tt_rnn_crf_%i_%i.ckpt' % (dataset,train_size,i))
            
            # Procedure for adding samples to training set via M1-M2 combination
            y_pred_lstm,_,scores_lstm = model1.predict(X_holdout,doc_len_holdout)
            #print('y_pred_lstm: ', y_pred_lstm)
            #print('scores lstm: ', scores_lstm)
            
            y_pred_rnn,_,scores_rnn = model2.predict(X_holdout,doc_len_holdout)
            #print('y_pred_rnn: ', y_pred_rnn)
            #print('scores rnn: ', scores_rnn)

            print('Before M1-M2 iteration, doc_len_holdout array size:', doc_len_holdout.size)
            print('Before M1-M2 iteration, X_train array:', X_train.size)

            val1 = []
            # For adding samples to training set through predictions of M1 and M2 on set S
            for x in range(y_pred_lstm.shape[0]):
              if(np.array_equiv(y_pred_lstm[x], y_pred_rnn[x]) and (min(scores_lstm[x], scores_rnn[x])>=holdout_confidence)):
                val1.insert(x, True)
              else:
                val1.insert(x, False)   
            
            val_size1 = np.sum(val1)
            print('Val size 1: ', val_size1)
            print('For M1-M2 combination, iteration %i: adding %i samples from holdout to train' % (i+1, val_size1))
            X_train = np.vstack((X_train,X_holdout[val1]))
            print('Printing X_train after adding from holdout', X_train.shape)
            y_train = np.vstack((y_train,y_pred_lstm[val1]))
            print('Printing y_train after adding from holdout', y_train.shape)
            doc_len_train = np.hstack((doc_len_train,doc_len_holdout[val1]))
            print('Printing doc_len_train after adding from holdout', doc_len_train.shape)
            val_inv1 = np.invert(val1)
            invert_size1 = np.sum(val_inv1)
            print('Printing inverted val size: ', invert_size1)
            X_holdout = X_holdout[val_inv1]
            print('Printing X_holdout after removing from holdout', X_holdout.shape)
            doc_len_holdout = doc_len_holdout[val_inv1]
            print('Printing doc_len_holdout after removing from holdout', doc_len_holdout.shape)

            print('After M1-M2 iteration, doc_len_holdout array:', doc_len_holdout.size)
            print('After M1-M2 iteration, X_train array:', X_train.size)
            

            model3.train(X_train,y_train,doc_len_train,
                        batch_size=batch_size_s,patience=patience_s,
                        validation_data=(X_val,y_val,doc_len_val),
                        savebest=True,filepath='/content/drive/MyDrive/Pubmed/SavedModels/%s_tt_gru_crf_%i_%i.ckpt' % (dataset,train_size,i))
            model3.load('/content/drive/MyDrive/Pubmed/SavedModels/%s_tt_gru_crf_%i_%i.ckpt' % (dataset,train_size,i))
            
            # Procedure for adding samples to training set via M1-M3 combination
            y_pred_gru,_,scores_gru = model3.predict(X_holdout,doc_len_holdout)
            #print('y_pred_gru: ', y_pred_gru.shape)
            #print('scores gru: ', scores_gru.shape)

            y_pred_lstm,_,scores_lstm = model1.predict(X_holdout,doc_len_holdout)
            #print('y_pred_lstm: ', y_pred_lstm.shape)
            #print('scores_lstm: ', scores_lstm.shape)

            print('Before M1-M3 iteration, doc_len_holdout array:', doc_len_holdout.size)
            print('Before M1-M3 iteration, X_train array:', X_train.size)

            val2 = []
            for x in range(y_pred_gru.shape[0]):
              if(np.array_equiv(y_pred_lstm[x], y_pred_gru[x]) and (min(scores_lstm[x], scores_gru[x])>=holdout_confidence)):
                val2.insert(x, True)
              else:
                val2.insert(x, False)
                
            val_size2 = np.sum(val2)
            print('Val size 2: ', val_size2)
            print('iteration %i: adding %i samples from holdout to train' % (i+1, val_size2))
            X_train = np.vstack((X_train,X_holdout[val2]))
            print('Printing X_train after adding from holdout', X_train.shape)
            y_train = np.vstack((y_train,y_pred_gru[val2]))
            print('Printing y_train after adding from holdout', y_train.shape)
            doc_len_train = np.hstack((doc_len_train,doc_len_holdout[val2]))
            print('Printing doc_len_train after adding from holdout', doc_len_train.shape)
            val_inv2 = np.invert(val2)
            invert_size2 = np.sum(val_inv2)
            print('Printing inverted val size: ', invert_size2)
            X_holdout = X_holdout[val_inv2]
            print('Printing X_holdout after adding from holdout', X_holdout.shape)
            doc_len_holdout = doc_len_holdout[val_inv2]
            print('Printing doc_len_holdout after adding from holdout', doc_len_holdout.shape)    

            print('After M1-M3 iteration, doc_len_holdout array:', doc_len_holdout.size)
            print('After M1-M3 iteration, X_train array:', X_train.size)  
            
            # Procedure for adding samples to training set via M2-M3 combination
            y_pred_gru,_,scores_gru = model3.predict(X_holdout,doc_len_holdout)
            print('y_pred_gru: ', y_pred_gru.shape)
            print('scores gru: ', scores_gru.shape)

            y_pred_rnn,_,scores_rnn = model2.predict(X_holdout,doc_len_holdout)
            print('y_pred_rnn: ', y_pred_rnn.shape)
            print('scores_rnn: ', scores_rnn.shape)

            print('Before M2-M3 iteration, doc_len_holdout array:', doc_len_holdout.size)
            print('Before M2-M3 iteration, X_train array:', X_train.size)
            
            val3 = []
            for x in range(y_pred_gru.shape[0]):
              if(np.array_equiv(y_pred_rnn[x], y_pred_gru[x]) and (min(scores_rnn[x], scores_gru[x])>=holdout_confidence)):
                val3.insert(x, True)
              else:
                val3.insert(x, False)
            
            val_size3 = np.sum(val3)
            print('Val size-3: ', val_size3)
            print('iteration %i: adding %i samples from holdout to train' % (i+1, val_size3))
            X_train = np.vstack((X_train,X_holdout[val3]))
            print('Printing X_train after adding from holdout', X_train.shape)
            y_train = np.vstack((y_train,y_pred_gru[val3]))
            print('Printing y_train after adding from holdout', y_train.shape)
            doc_len_train = np.hstack((doc_len_train,doc_len_holdout[val3]))
            print('Printing doc_len_train after adding from holdout', doc_len_train.shape)
            val_inv3 = np.invert(val3)
            invert_size3 = np.sum(val_inv3)
            print('Printing inverted val size: ', invert_size3)
            X_holdout = X_holdout[val_inv3]
            print('Printing X_holdout after adding from holdout', X_holdout.shape)
            doc_len_holdout = doc_len_holdout[val_inv3]
            print('Printing doc_len_holdout after adding from holdout', doc_len_holdout.shape)
            
            print('After M2-M3 iteration, doc_len_holdout array:', doc_len_holdout.size)
            print('After M2-M3 iteration, X_train array:', X_train.size)

            filter_size = val_size1 + val_size2 + val_size3
            print('Filter size for this iteration: ', filter_size)

            # evaluate on test set for M1
            y_preds_l_,_,_ = model1.predict(X_test,doc_len_test)
            y_predl = []
            for y_pred1_,l in zip(y_preds_l_,doc_len_test):
                y = [idx2label[l] for l in y_pred1_[:l]]
                y_predl.append(y)
            
            evaluator1 = Evaluator(y_true, y_predl, tags=['ENT'], loader="list")
            results1, results_by_tag1 = evaluator1.evaluate()
            
            precision1 = results1['exact']['precision']
            recall1 = results1['exact']['recall']
            f1_1 = results1['exact']['f1']

            print('Test set evaluation for BiLSTM CRF iteration %i results on %i samples' % (i+1,num_samples))
            print('precision:',precision1)
            print('recall:',recall1)
            print('f1:',f1_1)
            print()

            # evaluate on test set for M2
            y_preds_r_,_,_ = model2.predict(X_test,doc_len_test)
            y_predr = []
            for y_pred2_,l in zip(y_preds_r_,doc_len_test):
                y = [idx2label[l] for l in y_pred2_[:l]]
                y_predr.append(y)
            
            evaluator2 = Evaluator(y_true, y_predr, tags=['ENT'], loader="list")
            results2, results_by_tag2 = evaluator2.evaluate()
            
            precision2 = results2['exact']['precision']
            recall2 = results2['exact']['recall']
            f1_2 = results2['exact']['f1']

            print('Test set evaluation for BiRNN CRF iteration %i results on %i samples' % (i+1,num_samples))
            print('precision:',precision2)
            print('recall:',recall2)
            print('f1:',f1_2)
            print()

            # evaluate on test set for M3
            y_preds_g_,_,_ = model3.predict(X_test,doc_len_test)
            y_predg = []
            for y_pred3_,l in zip(y_preds_g_,doc_len_test):
                y = [idx2label[l] for l in y_pred3_[:l]]
                y_predg.append(y)
            
            evaluator3 = Evaluator(y_true, y_predg, tags=['ENT'], loader="list")
            results3, results_by_tag3 = evaluator3.evaluate()
            
            precision3 = results3['exact']['precision']
            recall3 = results3['exact']['recall']
            f1_3 = results3['exact']['f1']

            print('Test set evaluation for BiGRU CRF iteration %i results on %i samples' % (i+1,num_samples))
            print('precision:',precision3)
            print('recall:',recall3)
            print('f1:',f1_3)
            print()
            
            i += 1

            # track size of training set after each iteration of semi-supervised training
            with open('/content/drive/MyDrive/Pubmed/Asymmetric/%s_tritrain_datasize_%i.pkl' % (dataset,train_size),'wb') as f:
              pickle.dump(training_sizes,f)
            np.save("/content/drive/MyDrive/Pubmed/Asymmetric/%s_X_train_%i_it_%i.npy" % (dataset,data_size,i+1),X_train)
            np.save("/content/drive/MyDrive/Pubmed/Asymmetric/%s_y_train_%i_it_%i.npy" % (dataset,data_size,i+1),y_train)
            np.save("/content/drive/MyDrive/Pubmed/Asymmetric/%s_X_val_%i_it_%i.npy" % (dataset,data_size,i+1),X_val)
            np.save("/content/drive/MyDrive/Pubmed/Asymmetric/%s_y_val_%i_it_%i.npy" % (dataset,data_size,i+1),y_val)
            with open('/content/drive/MyDrive/Pubmed/Asymmetric/%s_senlens_%i_it_%i.pkl' % (dataset,data_size,i+1),'wb') as f:
              pickle.dump(doc_len_train,f)
            with open('/content/drive/MyDrive/Pubmed/Asymmetric/%s_senlens_val_%i_it_%i.pkl' % (dataset,data_size,i+1),'wb') as f:
              pickle.dump(doc_len_val,f)
# Out:
# Training in the dataset loop BC2GM 2000
# train size: 1600
# WARNING:tensorflow:From <ipython-input-7-8b90d78dcfaa>:54: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# 2022-04-28 05:56:45 tensorflow WARNING: From <ipython-input-7-8b90d78dcfaa>:54: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# 2022-04-28 05:56:45 tensorflow WARNING:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# WARNING:tensorflow:From <ipython-input-7-8b90d78dcfaa>:59: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# 2022-04-28 05:56:45 tensorflow WARNING: From <ipython-input-7-8b90d78dcfaa>:59: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From <ipython-input-7-8b90d78dcfaa>:60: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# 2022-04-28 05:56:45 tensorflow WARNING: From <ipython-input-7-8b90d78dcfaa>:60: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/rnn.py:464: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# 2022-04-28 05:56:45 tensorflow WARNING: From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/rnn.py:464: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/rnn_cell_impl.py:958: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# 2022-04-28 05:56:45 tensorflow WARNING: From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/rnn_cell_impl.py:958: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/rnn_cell_impl.py:962: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# 2022-04-28 05:56:45 tensorflow WARNING: From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/rnn_cell_impl.py:962: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/rnn.py:244: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# 2022-04-28 05:56:45 tensorflow WARNING: From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/rnn.py:244: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From <ipython-input-7-8b90d78dcfaa>:66: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# 2022-04-28 05:56:45 tensorflow WARNING: From <ipython-input-7-8b90d78dcfaa>:66: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# 2022-04-28 05:56:45 tensorflow WARNING: From /tensorflow-1.15.2/python3.7/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From <ipython-input-8-d3f6608e3745>:59: BasicRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.SimpleRNNCell, and will be replaced by that in Tensorflow 2.0.
# 2022-04-28 05:56:52 tensorflow WARNING: From <ipython-input-8-d3f6608e3745>:59: BasicRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.SimpleRNNCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From <ipython-input-9-da53b1a75205>:59: GRUCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.GRUCell, and will be replaced by that in Tensorflow 2.0.
# 2022-04-28 05:56:54 tensorflow WARNING: From <ipython-input-9-da53b1a75205>:59: GRUCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.GRUCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/rnn_cell_impl.py:565: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# 2022-04-28 05:56:54 tensorflow WARNING: From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/rnn_cell_impl.py:565: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Entered BiLSTM-CRF. Training network on 1600 documents, validation on 400 documents
#
# training time: 3.61
# epoch 1 training f1: 0.0264
#
# epoch 1 validation f1: 0.0298
#
# training time: 1.95
# epoch 2 training f1: 0.0255
#
# epoch 2 validation f1: 0.0257
#
# training time: 1.96
# epoch 3 training f1: 0.0230
#
# epoch 3 validation f1: 0.0246
#
# training time: 1.98
# epoch 4 training f1: 0.0137
#
# epoch 4 validation f1: 0.0000
#
# training time: 1.98
# epoch 5 training f1: 0.0034
#
# epoch 5 validation f1: 0.0000
#
# training time: 2.05
# epoch 6 training f1: 0.0000
#
# epoch 6 validation f1: 0.0000
#
# training time: 1.96
# epoch 7 training f1: 0.0010
#
# epoch 7 validation f1: 0.0000
#
# training time: 1.96
# epoch 8 training f1: 0.0020
#
# epoch 8 validation f1: 0.0000
#
# training time: 1.94
# epoch 9 training f1: 0.0021
#
# epoch 9 validation f1: 0.0041
#
# training time: 1.96
# epoch 10 training f1: 0.0031
#
# epoch 10 validation f1: 0.0082
#
# training time: 1.97
# epoch 11 training f1: 0.0112
#
# epoch 11 validation f1: 0.0123
#
# training time: 2.00
# epoch 12 training f1: 0.0100
#
# epoch 12 validation f1: 0.0121
#
# training time: 1.96
# epoch 13 training f1: 0.0150
#
# epoch 13 validation f1: 0.0120
#
# training time: 1.95
# epoch 14 training f1: 0.0226
#
# epoch 14 validation f1: 0.0119
#
# training time: 1.88
# epoch 15 training f1: 0.0176
#
# epoch 15 validation f1: 0.0196
#
# training time: 1.97
# epoch 16 training f1: 0.0345
#
# epoch 16 validation f1: 0.0156
#
# training time: 2.08
# epoch 17 training f1: 0.0281
#
# epoch 17 validation f1: 0.0155
#
# training time: 1.94
# epoch 18 training f1: 0.0316
#
# epoch 18 validation f1: 0.0269
#
# training time: 1.94
# epoch 19 training f1: 0.0362
#
# epoch 19 validation f1: 0.0299
#
# training time: 1.94
# epoch 20 training f1: 0.0406
#
# epoch 20 validation f1: 0.0261
#
# training time: 1.95
# epoch 21 training f1: 0.0534
#
# epoch 21 validation f1: 0.0333
#
# training time: 2.11
# epoch 22 training f1: 0.0593
#
# epoch 22 validation f1: 0.0436
#
# training time: 1.95
# epoch 23 training f1: 0.0750
#
# epoch 23 validation f1: 0.0432
#
# training time: 2.05
# epoch 24 training f1: 0.0724
#
# epoch 24 validation f1: 0.0534
#
# training time: 1.97
# epoch 25 training f1: 0.0750
#
# epoch 25 validation f1: 0.0626
#
# training time: 1.95
# epoch 26 training f1: 0.0837
#
# epoch 26 validation f1: 0.0589
#
# training time: 1.94
# epoch 27 training f1: 0.0985
#
# epoch 27 validation f1: 0.0835
#
# training time: 2.11
# epoch 28 training f1: 0.1054
#
# epoch 28 validation f1: 0.0745
#
# training time: 1.95
# epoch 29 training f1: 0.1007
#
# epoch 29 validation f1: 0.0995
#
# training time: 1.94
# epoch 30 training f1: 0.1197
#
# epoch 30 validation f1: 0.0708
#
# training time: 1.94
# epoch 31 training f1: 0.1160
#
# epoch 31 validation f1: 0.1083
#
# training time: 1.98
# epoch 32 training f1: 0.1225
#
# epoch 32 validation f1: 0.1147
#
# training time: 1.96
# epoch 33 training f1: 0.1362
#
# epoch 33 validation f1: 0.1159
#
# training time: 2.06
# epoch 34 training f1: 0.1325
#
# epoch 34 validation f1: 0.1347
#
# training time: 2.01
# epoch 35 training f1: 0.1389
#
# epoch 35 validation f1: 0.1313
#
# training time: 1.95
# epoch 36 training f1: 0.1522
#
# epoch 36 validation f1: 0.1307
#
# training time: 1.98
# epoch 37 training f1: 0.1626
#
# epoch 37 validation f1: 0.1366
#
# training time: 1.98
# epoch 38 training f1: 0.1479
#
# epoch 38 validation f1: 0.1418
#
# training time: 2.08
# epoch 39 training f1: 0.1698
#
# epoch 39 validation f1: 0.1360
#
# training time: 1.93
# epoch 40 training f1: 0.1715
#
# epoch 40 validation f1: 0.1384
#
# training time: 1.95
# epoch 41 training f1: 0.1667
#
# epoch 41 validation f1: 0.1493
#
# training time: 1.95
# epoch 42 training f1: 0.1771
#
# epoch 42 validation f1: 0.1460
#
# training time: 1.97
# epoch 43 training f1: 0.1851
#
# epoch 43 validation f1: 0.1521
#
# training time: 1.95
# epoch 44 training f1: 0.1816
#
# epoch 44 validation f1: 0.1490
#
# training time: 1.95
# epoch 45 training f1: 0.1907
#
# epoch 45 validation f1: 0.1583
#
# training time: 1.99
# epoch 46 training f1: 0.1804
#
# epoch 46 validation f1: 0.1619
#
# training time: 2.00
# epoch 47 training f1: 0.1883
#
# epoch 47 validation f1: 0.1623
#
# training time: 1.95
# epoch 48 training f1: 0.1933
#
# epoch 48 validation f1: 0.1664
#
# training time: 1.96
# epoch 49 training f1: 0.1962
#
# epoch 49 validation f1: 0.1560
#
# training time: 1.96
# epoch 50 training f1: 0.2075
#
# epoch 50 validation f1: 0.1632
#
# training time: 2.14
# epoch 51 training f1: 0.2113
#
# epoch 51 validation f1: 0.1557
#
# training time: 1.96
# epoch 52 training f1: 0.2202
#
# epoch 52 validation f1: 0.1653
#
# training time: 1.94
# epoch 53 training f1: 0.2218
#
# epoch 53 validation f1: 0.1590
#
# training time: 1.94
# epoch 54 training f1: 0.2139
#
# epoch 54 validation f1: 0.1594
#
# training time: 1.99
# epoch 55 training f1: 0.2141
#
# epoch 55 validation f1: 0.1689
#
# training time: 1.95
# epoch 56 training f1: 0.2250
#
# epoch 56 validation f1: 0.1651
#
# training time: 2.09
# epoch 57 training f1: 0.2231
#
# epoch 57 validation f1: 0.1676
#
# training time: 1.97
# epoch 58 training f1: 0.2283
#
# epoch 58 validation f1: 0.1712
#
# training time: 1.92
# epoch 59 training f1: 0.2386
#
# epoch 59 validation f1: 0.1768
#
# training time: 1.97
# epoch 60 training f1: 0.2246
#
# epoch 60 validation f1: 0.1781
#
# training time: 2.09
# epoch 61 training f1: 0.2405
#
# epoch 61 validation f1: 0.1743
#
# training time: 1.99
# epoch 62 training f1: 0.2357
#
# epoch 62 validation f1: 0.1755
#
# training time: 1.96
# epoch 63 training f1: 0.2416
#
# epoch 63 validation f1: 0.1859
#
# training time: 1.95
# epoch 64 training f1: 0.2472
#
# epoch 64 validation f1: 0.1979
#
# training time: 1.94
# epoch 65 training f1: 0.2461
#
# epoch 65 validation f1: 0.1987
#
# training time: 1.96
# epoch 66 training f1: 0.2610
#
# epoch 66 validation f1: 0.1997
#
# training time: 1.96
# epoch 67 training f1: 0.2580
#
# epoch 67 validation f1: 0.2049
#
# training time: 1.97
# epoch 68 training f1: 0.2427
#
# epoch 68 validation f1: 0.2014
#
# training time: 2.09
# epoch 69 training f1: 0.2644
#
# epoch 69 validation f1: 0.1876
#
# training time: 1.97
# epoch 70 training f1: 0.2546
#
# epoch 70 validation f1: 0.2038
#
# training time: 1.96
# epoch 71 training f1: 0.2645
#
# epoch 71 validation f1: 0.2139
#
# training time: 1.97
# epoch 72 training f1: 0.2683
#
# epoch 72 validation f1: 0.2141
#
# training time: 1.94
# epoch 73 training f1: 0.2559
#
# epoch 73 validation f1: 0.2030
#
# training time: 1.95
# epoch 74 training f1: 0.2690
#
# epoch 74 validation f1: 0.2008
#
# training time: 2.12
# epoch 75 training f1: 0.2678
#
# epoch 75 validation f1: 0.2149
#
# training time: 1.94
# epoch 76 training f1: 0.2850
#
# epoch 76 validation f1: 0.2305
#
# training time: 1.93
# epoch 77 training f1: 0.2889
#
# epoch 77 validation f1: 0.2208
#
# training time: 1.94
# epoch 78 training f1: 0.2862
#
# epoch 78 validation f1: 0.2210
#
# training time: 1.95
# epoch 79 training f1: 0.2851
#
# epoch 79 validation f1: 0.2184
#
# training time: 1.99
# epoch 80 training f1: 0.2895
#
# epoch 80 validation f1: 0.1966
#
# training time: 1.98
# epoch 81 training f1: 0.2807
#
# epoch 81 validation f1: 0.2216
#
# training time: 1.97
# epoch 82 training f1: 0.2990
#
# epoch 82 validation f1: 0.2201
#
# training time: 1.95
# epoch 83 training f1: 0.2955
#
# epoch 83 validation f1: 0.2225
#
# training time: 1.94
# epoch 84 training f1: 0.2965
#
# epoch 84 validation f1: 0.2282
#
# training time: 1.94
# epoch 85 training f1: 0.3127
#
# epoch 85 validation f1: 0.2129
#
# training time: 1.97
# epoch 86 training f1: 0.3033
#
# epoch 86 validation f1: 0.2295
#
# training time: 1.99
# epoch 87 training f1: 0.3237
#
# epoch 87 validation f1: 0.2179
#
# training time: 1.94
# epoch 88 training f1: 0.3171
#
# epoch 88 validation f1: 0.2128
#
# training time: 2.07
# epoch 89 training f1: 0.3180
#
# epoch 89 validation f1: 0.2275
#
# training time: 1.97
# epoch 90 training f1: 0.3181
#
# epoch 90 validation f1: 0.1876
#
# training time: 2.00
# epoch 91 training f1: 0.3239
#
# epoch 91 validation f1: 0.1944
#
# training time: 2.10
# epoch 92 training f1: 0.3280
#
# epoch 92 validation f1: 0.2210
#
# training time: 1.97
# epoch 93 training f1: 0.3334
#
# epoch 93 validation f1: 0.2161
#
# training time: 1.98
# epoch 94 training f1: 0.3228
#
# epoch 94 validation f1: 0.2101
#
# training time: 1.98
# epoch 95 training f1: 0.3333
#
# epoch 95 validation f1: 0.2243
#
# training time: 1.95
# epoch 96 training f1: 0.3378
#
# epoch 96 validation f1: 0.2118
# Entered BiRNN-CRF. Training network on 1600 documents, validation on 400 documents
#
# training time: 2.00
# epoch 1 training f1: 0.0207
#
# epoch 1 validation f1: 0.0155
#
# training time: 1.59
# epoch 2 training f1: 0.0188
#
# epoch 2 validation f1: 0.0194
#
# training time: 1.58
# epoch 3 training f1: 0.0244
#
# epoch 3 validation f1: 0.0265
#
# training time: 1.58
# epoch 4 training f1: 0.0147
#
# epoch 4 validation f1: 0.0000
#
# training time: 1.59
# epoch 5 training f1: 0.0091
#
# epoch 5 validation f1: 0.0081
#
# training time: 1.63
# epoch 6 training f1: 0.0142
#
# epoch 6 validation f1: 0.0151
#
# training time: 1.59
# epoch 7 training f1: 0.0507
#
# epoch 7 validation f1: 0.0362
#
# training time: 1.61
# epoch 8 training f1: 0.0470
#
# epoch 8 validation f1: 0.0375
#
# training time: 1.64
# epoch 9 training f1: 0.0584
#
# epoch 9 validation f1: 0.0671
#
# training time: 1.60
# epoch 10 training f1: 0.0645
#
# epoch 10 validation f1: 0.0725
#
# training time: 1.57
# epoch 11 training f1: 0.0734
#
# epoch 11 validation f1: 0.0807
#
# training time: 1.61
# epoch 12 training f1: 0.0770
#
# epoch 12 validation f1: 0.1010
#
# training time: 1.58
# epoch 13 training f1: 0.0878
#
# epoch 13 validation f1: 0.0987
#
# training time: 1.62
# epoch 14 training f1: 0.0925
#
# epoch 14 validation f1: 0.1039
#
# training time: 1.60
# epoch 15 training f1: 0.1014
#
# epoch 15 validation f1: 0.1056
#
# training time: 1.59
# epoch 16 training f1: 0.1035
#
# epoch 16 validation f1: 0.1257
#
# training time: 1.60
# epoch 17 training f1: 0.1027
#
# epoch 17 validation f1: 0.1214
#
# training time: 1.61
# epoch 18 training f1: 0.1153
#
# epoch 18 validation f1: 0.1263
#
# training time: 1.73
# epoch 19 training f1: 0.1210
#
# epoch 19 validation f1: 0.1324
#
# training time: 1.59
# epoch 20 training f1: 0.1370
#
# epoch 20 validation f1: 0.1372
#
# training time: 1.61
# epoch 21 training f1: 0.1276
#
# epoch 21 validation f1: 0.1320
#
# training time: 1.65
# epoch 22 training f1: 0.1333
#
# epoch 22 validation f1: 0.1389
#
# training time: 1.61
# epoch 23 training f1: 0.1391
#
# epoch 23 validation f1: 0.1545
#
# training time: 1.65
# epoch 24 training f1: 0.1452
#
# epoch 24 validation f1: 0.1471
#
# training time: 1.78
# epoch 25 training f1: 0.1451
#
# epoch 25 validation f1: 0.1600
#
# training time: 1.60
# epoch 26 training f1: 0.1718
#
# epoch 26 validation f1: 0.1679
#
# training time: 1.61
# epoch 27 training f1: 0.1632
#
# epoch 27 validation f1: 0.1755
#
# training time: 1.62
# epoch 28 training f1: 0.1738
#
# epoch 28 validation f1: 0.1853
#
# training time: 1.62
# epoch 29 training f1: 0.1666
#
# epoch 29 validation f1: 0.1884
#
# training time: 1.64
# epoch 30 training f1: 0.1875
#
# epoch 30 validation f1: 0.1757
#
# training time: 1.65
# epoch 31 training f1: 0.1912
#
# epoch 31 validation f1: 0.1950
#
# training time: 1.64
# epoch 32 training f1: 0.2045
#
# epoch 32 validation f1: 0.1967
#
# training time: 1.62
# epoch 33 training f1: 0.2097
#
# epoch 33 validation f1: 0.1984
#
# training time: 1.60
# epoch 34 training f1: 0.2116
#
# epoch 34 validation f1: 0.2136
#
# training time: 1.64
# epoch 35 training f1: 0.2135
#
# epoch 35 validation f1: 0.2017
#
# training time: 1.63
# epoch 36 training f1: 0.2174
#
# epoch 36 validation f1: 0.2022
#
# training time: 1.62
# epoch 37 training f1: 0.2160
#
# epoch 37 validation f1: 0.2045
#
# training time: 1.62
# epoch 38 training f1: 0.2413
#
# epoch 38 validation f1: 0.2203
#
# training time: 1.59
# epoch 39 training f1: 0.2426
#
# epoch 39 validation f1: 0.2188
#
# training time: 1.61
# epoch 40 training f1: 0.2429
#
# epoch 40 validation f1: 0.2244
#
# training time: 1.60
# epoch 41 training f1: 0.2276
#
# epoch 41 validation f1: 0.2130
#
# training time: 1.58
# epoch 42 training f1: 0.2392
#
# epoch 42 validation f1: 0.2192
#
# training time: 1.61
# epoch 43 training f1: 0.2490
#
# epoch 43 validation f1: 0.2313
#
# training time: 1.60
# epoch 44 training f1: 0.2594
#
# epoch 44 validation f1: 0.2334
#
# training time: 1.60
# epoch 45 training f1: 0.2690
#
# epoch 45 validation f1: 0.2262
#
# training time: 1.63
# epoch 46 training f1: 0.2634
#
# epoch 46 validation f1: 0.2404
#
# training time: 1.59
# epoch 47 training f1: 0.2696
#
# epoch 47 validation f1: 0.2338
#
# training time: 1.61
# epoch 48 training f1: 0.2774
#
# epoch 48 validation f1: 0.2311
#
# training time: 1.61
# epoch 49 training f1: 0.2703
#
# epoch 49 validation f1: 0.2316
#
# training time: 1.77
# epoch 50 training f1: 0.2777
#
# epoch 50 validation f1: 0.2382
#
# training time: 1.59
# epoch 51 training f1: 0.2780
#
# epoch 51 validation f1: 0.2408
#
# training time: 1.58
# epoch 52 training f1: 0.2823
#
# epoch 52 validation f1: 0.2372
#
# training time: 1.63
# epoch 53 training f1: 0.2812
#
# epoch 53 validation f1: 0.2332
#
# training time: 1.59
# epoch 54 training f1: 0.2960
#
# epoch 54 validation f1: 0.2342
#
# training time: 1.61
# epoch 55 training f1: 0.2887
#
# epoch 55 validation f1: 0.2430
#
# training time: 1.61
# epoch 56 training f1: 0.2977
#
# epoch 56 validation f1: 0.2358
#
# training time: 1.62
# epoch 57 training f1: 0.3037
#
# epoch 57 validation f1: 0.2467
#
# training time: 1.56
# epoch 58 training f1: 0.3158
#
# epoch 58 validation f1: 0.2347
#
# training time: 1.63
# epoch 59 training f1: 0.3042
#
# epoch 59 validation f1: 0.2396
#
# training time: 1.62
# epoch 60 training f1: 0.3130
#
# epoch 60 validation f1: 0.2476
#
# training time: 1.61
# epoch 61 training f1: 0.3052
#
# epoch 61 validation f1: 0.2637
#
# training time: 1.63
# epoch 62 training f1: 0.3023
#
# epoch 62 validation f1: 0.2593
#
# training time: 1.62
# epoch 63 training f1: 0.3142
#
# epoch 63 validation f1: 0.2653
#
# training time: 1.62
# epoch 64 training f1: 0.3064
#
# epoch 64 validation f1: 0.2592
#
# training time: 1.60
# epoch 65 training f1: 0.2996
#
# epoch 65 validation f1: 0.2663
#
# training time: 1.66
# epoch 66 training f1: 0.3367
#
# epoch 66 validation f1: 0.2503
#
# training time: 1.63
# epoch 67 training f1: 0.3271
#
# epoch 67 validation f1: 0.2693
#
# training time: 1.62
# epoch 68 training f1: 0.3153
#
# epoch 68 validation f1: 0.2715
#
# training time: 1.61
# epoch 69 training f1: 0.3276
#
# epoch 69 validation f1: 0.2625
#
# training time: 1.61
# epoch 70 training f1: 0.3256
#
# epoch 70 validation f1: 0.2688
#
# training time: 1.65
# epoch 71 training f1: 0.3239
#
# epoch 71 validation f1: 0.2624
#
# training time: 1.61
# epoch 72 training f1: 0.3415
#
# epoch 72 validation f1: 0.2550
#
# training time: 1.61
# epoch 73 training f1: 0.3347
#
# epoch 73 validation f1: 0.2582
#
# training time: 1.59
# epoch 74 training f1: 0.3258
#
# epoch 74 validation f1: 0.2770
#
# training time: 1.64
# epoch 75 training f1: 0.3292
#
# epoch 75 validation f1: 0.2801
#
# training time: 1.61
# epoch 76 training f1: 0.3319
#
# epoch 76 validation f1: 0.2712
#
# training time: 1.62
# epoch 77 training f1: 0.3281
#
# epoch 77 validation f1: 0.2667
#
# training time: 1.60
# epoch 78 training f1: 0.3531
#
# epoch 78 validation f1: 0.2702
#
# training time: 1.64
# epoch 79 training f1: 0.3359
#
# epoch 79 validation f1: 0.2813
#
# training time: 1.61
# epoch 80 training f1: 0.3525
#
# epoch 80 validation f1: 0.2690
#
# training time: 1.59
# epoch 81 training f1: 0.3561
#
# epoch 81 validation f1: 0.2779
#
# training time: 1.60
# epoch 82 training f1: 0.3478
#
# epoch 82 validation f1: 0.2765
#
# training time: 1.59
# epoch 83 training f1: 0.3522
#
# epoch 83 validation f1: 0.2760
#
# training time: 1.75
# epoch 84 training f1: 0.3556
#
# epoch 84 validation f1: 0.2658
#
# training time: 1.61
# epoch 85 training f1: 0.3583
#
# epoch 85 validation f1: 0.2720
#
# training time: 1.60
# epoch 86 training f1: 0.3704
#
# epoch 86 validation f1: 0.2893
#
# training time: 1.60
# epoch 87 training f1: 0.3406
#
# epoch 87 validation f1: 0.2788
#
# training time: 1.62
# epoch 88 training f1: 0.3620
#
# epoch 88 validation f1: 0.2828
#
# training time: 1.66
# epoch 89 training f1: 0.3742
#
# epoch 89 validation f1: 0.2796
#
# training time: 1.62
# epoch 90 training f1: 0.3678
#
# epoch 90 validation f1: 0.2695
#
# training time: 1.66
# epoch 91 training f1: 0.3590
#
# epoch 91 validation f1: 0.2721
#
# training time: 1.61
# epoch 92 training f1: 0.3692
#
# epoch 92 validation f1: 0.2613
#
# training time: 1.58
# epoch 93 training f1: 0.3706
#
# epoch 93 validation f1: 0.2809
#
# training time: 1.62
# epoch 94 training f1: 0.3761
#
# epoch 94 validation f1: 0.2857
#
# training time: 1.63
# epoch 95 training f1: 0.3751
#
# epoch 95 validation f1: 0.2759
#
# training time: 1.62
# epoch 96 training f1: 0.3695
#
# epoch 96 validation f1: 0.2846
#
# training time: 1.60
# epoch 97 training f1: 0.3734
#
# epoch 97 validation f1: 0.2717
#
# training time: 1.59
# epoch 98 training f1: 0.3700
#
# epoch 98 validation f1: 0.2672
#
# training time: 1.60
# epoch 99 training f1: 0.3829
#
# epoch 99 validation f1: 0.2681
#
# training time: 1.63
# epoch 100 training f1: 0.3645
#
# epoch 100 validation f1: 0.2770
#
# training time: 1.62
# epoch 101 training f1: 0.3738
#
# epoch 101 validation f1: 0.2769
#
# training time: 1.64
# epoch 102 training f1: 0.3703
#
# epoch 102 validation f1: 0.2788
#
# training time: 1.60
# epoch 103 training f1: 0.3777
#
# epoch 103 validation f1: 0.2868
#
# training time: 1.61
# epoch 104 training f1: 0.3827
#
# epoch 104 validation f1: 0.2617
#
# training time: 1.59
# epoch 105 training f1: 0.3944
#
# epoch 105 validation f1: 0.2626
#
# training time: 1.62
# epoch 106 training f1: 0.3919
#
# epoch 106 validation f1: 0.2719
# INFO:tensorflow:Restoring parameters from /content/drive/MyDrive/Pubmed/SavedModels/BC2GM_tt_lstm_crf_1600_0.ckpt
# 2022-04-28 06:05:28 tensorflow INFO: Restoring parameters from /content/drive/MyDrive/Pubmed/SavedModels/BC2GM_tt_lstm_crf_1600_0.ckpt
# INFO:tensorflow:Restoring parameters from /content/drive/MyDrive/Pubmed/SavedModels/BC2GM_tt_rnn_crf_1600_0.ckpt
# 2022-04-28 06:05:28 tensorflow INFO: Restoring parameters from /content/drive/MyDrive/Pubmed/SavedModels/BC2GM_tt_rnn_crf_1600_0.ckpt
# Before M1-M2 iteration, doc_len_holdout array size: 10574
# Before M1-M2 iteration, X_train array: 80000
# Val size 1:  2510
# For M1-M2 combination, iteration 1: adding 2510 samples from holdout to train
# Printing X_train after adding from holdout (4110, 50)
# Printing y_train after adding from holdout (4110, 50)
# Printing doc_len_train after adding from holdout (4110,)
# Printing inverted val size:  8064
# Printing X_holdout after removing from holdout (8064, 50)
# Printing doc_len_holdout after removing from holdout (8064,)
# After M1-M2 iteration, doc_len_holdout array: 8064
# After M1-M2 iteration, X_train array: 205500
# Entered BiGRU-CRF. Training network on 4110 documents, validation on 400 documents
#
# training time: 5.67
# epoch 1 training f1: 0.0116
#
# epoch 1 validation f1: 0.0283
#
# training time: 5.02
# epoch 2 training f1: 0.0122
#
# epoch 2 validation f1: 0.0347
#
# training time: 4.95
# epoch 3 training f1: 0.0171
#
# epoch 3 validation f1: 0.0063
#
# training time: 5.10
# epoch 4 training f1: 0.0198
#
# epoch 4 validation f1: 0.0204
#
# training time: 5.19
# epoch 5 training f1: 0.0279
#
# epoch 5 validation f1: 0.0231
#
# training time: 5.04
# epoch 6 training f1: 0.0321
#
# epoch 6 validation f1: 0.0298
#
# training time: 5.07
# epoch 7 training f1: 0.0357
#
# epoch 7 validation f1: 0.0269
#
# training time: 5.04
# epoch 8 training f1: 0.0467
#
# epoch 8 validation f1: 0.0336
#
# training time: 5.10
# epoch 9 training f1: 0.0508
#
# epoch 9 validation f1: 0.0347
#
# training time: 5.19
# epoch 10 training f1: 0.0572
#
# epoch 10 validation f1: 0.0444
#
# training time: 5.07
# epoch 11 training f1: 0.0624
#
# epoch 11 validation f1: 0.0324
#
# training time: 5.08
# epoch 12 training f1: 0.0587
#
# epoch 12 validation f1: 0.0346
#
# training time: 5.06
# epoch 13 training f1: 0.0708
#
# epoch 13 validation f1: 0.0402
#
# training time: 5.08
# epoch 14 training f1: 0.0650
#
# epoch 14 validation f1: 0.0523
#
# training time: 5.16
# epoch 15 training f1: 0.0741
#
# epoch 15 validation f1: 0.0574
#
# training time: 5.09
# epoch 16 training f1: 0.0815
#
# epoch 16 validation f1: 0.0566
#
# training time: 5.24
# epoch 17 training f1: 0.0814
#
# epoch 17 validation f1: 0.0519
#
# training time: 5.08
# epoch 18 training f1: 0.0898
#
# epoch 18 validation f1: 0.0555
#
# training time: 5.06
# epoch 19 training f1: 0.0901
#
# epoch 19 validation f1: 0.0682
#
# training time: 5.18
# epoch 20 training f1: 0.1020
#
# epoch 20 validation f1: 0.0883
#
# training time: 5.01
# epoch 21 training f1: 0.1113
#
# epoch 21 validation f1: 0.0844
#
# training time: 5.25
# epoch 22 training f1: 0.1096
#
# epoch 22 validation f1: 0.0876
#
# training time: 5.06
# epoch 23 training f1: 0.1169
#
# epoch 23 validation f1: 0.0969
#
# training time: 4.98
# epoch 24 training f1: 0.1229
#
# epoch 24 validation f1: 0.1040
#
# training time: 5.16
# epoch 25 training f1: 0.1302
#
# epoch 25 validation f1: 0.0949
#
# training time: 5.06
# epoch 26 training f1: 0.1269
#
# epoch 26 validation f1: 0.0985
#
# training time: 5.22
# epoch 27 training f1: 0.1367
#
# epoch 27 validation f1: 0.1009
#
# training time: 5.05
# epoch 28 training f1: 0.1339
#
# epoch 28 validation f1: 0.1025
#
# training time: 4.98
# epoch 29 training f1: 0.1329
#
# epoch 29 validation f1: 0.1280
#
# training time: 5.18
# epoch 30 training f1: 0.1394
#
# epoch 30 validation f1: 0.1202
#
# training time: 5.05
# epoch 31 training f1: 0.1511
#
# epoch 31 validation f1: 0.1166
#
# training time: 5.21
# epoch 32 training f1: 0.1442
#
# epoch 32 validation f1: 0.1323
#
# training time: 5.11
# epoch 33 training f1: 0.1604
#
# epoch 33 validation f1: 0.1368
#
# training time: 5.07
# epoch 34 training f1: 0.1553
#
# epoch 34 validation f1: 0.1440
#
# training time: 5.10
# epoch 35 training f1: 0.1534
#
# epoch 35 validation f1: 0.1482
#
# training time: 5.07
# epoch 36 training f1: 0.1627
#
# epoch 36 validation f1: 0.1512
#
# training time: 5.22
# epoch 37 training f1: 0.1769
#
# epoch 37 validation f1: 0.1518
#
# training time: 5.05
# epoch 38 training f1: 0.1709
#
# epoch 38 validation f1: 0.1524
#
# training time: 5.00
# epoch 39 training f1: 0.1652
#
# epoch 39 validation f1: 0.1602
#
# training time: 5.09
# epoch 40 training f1: 0.1753
#
# epoch 40 validation f1: 0.1625
#
# training time: 5.00
# epoch 41 training f1: 0.1805
#
# epoch 41 validation f1: 0.1633
#
# training time: 5.19
# epoch 42 training f1: 0.1757
#
# epoch 42 validation f1: 0.1790
#
# training time: 5.05
# epoch 43 training f1: 0.1843
#
# epoch 43 validation f1: 0.1775
#
# training time: 5.06
# epoch 44 training f1: 0.1899
#
# epoch 44 validation f1: 0.1848
#
# training time: 5.03
# epoch 45 training f1: 0.1890
#
# epoch 45 validation f1: 0.1902
#
# training time: 5.03
# epoch 46 training f1: 0.1996
#
# epoch 46 validation f1: 0.1824
#
# training time: 5.25
# epoch 47 training f1: 0.2054
#
# epoch 47 validation f1: 0.1970
#
# training time: 5.08
# epoch 48 training f1: 0.2068
#
# epoch 48 validation f1: 0.1901
#
# training time: 5.24
# epoch 49 training f1: 0.2170
#
# epoch 49 validation f1: 0.1886
#
# training time: 5.02
# epoch 50 training f1: 0.2141
#
# epoch 50 validation f1: 0.1899
#
# training time: 5.01
# epoch 51 training f1: 0.2167
#
# epoch 51 validation f1: 0.1922
#
# training time: 5.19
# epoch 52 training f1: 0.2233
#
# epoch 52 validation f1: 0.1938
#
# training time: 4.99
# epoch 53 training f1: 0.2151
#
# epoch 53 validation f1: 0.1964
#
# training time: 4.99
# epoch 54 training f1: 0.2313
#
# epoch 54 validation f1: 0.1818
#
# training time: 5.00
# epoch 55 training f1: 0.2330
#
# epoch 55 validation f1: 0.1934
#
# training time: 4.99
# epoch 56 training f1: 0.2294
#
# epoch 56 validation f1: 0.1993
#
# training time: 5.20
# epoch 57 training f1: 0.2443
#
# epoch 57 validation f1: 0.2148
#
# training time: 5.00
# epoch 58 training f1: 0.2485
#
# epoch 58 validation f1: 0.2160
#
# training time: 5.16
# epoch 59 training f1: 0.2553
#
# epoch 59 validation f1: 0.2043
#
# training time: 5.05
# epoch 60 training f1: 0.2666
#
# epoch 60 validation f1: 0.2208
#
# training time: 5.05
# epoch 61 training f1: 0.2513
#
# epoch 61 validation f1: 0.2098
#
# training time: 5.11
# epoch 62 training f1: 0.2664
#
# epoch 62 validation f1: 0.2102
#
# training time: 5.04
# epoch 63 training f1: 0.2729
#
# epoch 63 validation f1: 0.2019
#
# training time: 5.21
# epoch 64 training f1: 0.2840
#
# epoch 64 validation f1: 0.2047
#
# training time: 5.04
# epoch 65 training f1: 0.2825
#
# epoch 65 validation f1: 0.2172
#
# training time: 5.03
# epoch 66 training f1: 0.2980
#
# epoch 66 validation f1: 0.2167
#
# training time: 5.08
# epoch 67 training f1: 0.2908
#
# epoch 67 validation f1: 0.2326
#
# training time: 5.03
# epoch 68 training f1: 0.3071
#
# epoch 68 validation f1: 0.2316
#
# training time: 5.18
# epoch 69 training f1: 0.2995
#
# epoch 69 validation f1: 0.2178
#
# training time: 5.07
# epoch 70 training f1: 0.3232
#
# epoch 70 validation f1: 0.2177
#
# training time: 5.06
# epoch 71 training f1: 0.3223
#
# epoch 71 validation f1: 0.2377
#
# training time: 5.13
# epoch 72 training f1: 0.3497
#
# epoch 72 validation f1: 0.2227
#
# training time: 4.98
# epoch 73 training f1: 0.3317
#
# epoch 73 validation f1: 0.2235
#
# training time: 5.16
# epoch 74 training f1: 0.3237
#
# epoch 74 validation f1: 0.2397
#
# training time: 5.08
# epoch 75 training f1: 0.3400
#
# epoch 75 validation f1: 0.2402
#
# training time: 5.05
# epoch 76 training f1: 0.3529
#
# epoch 76 validation f1: 0.2336
#
# training time: 5.09
# epoch 77 training f1: 0.3497
#
# epoch 77 validation f1: 0.2448
#
# training time: 5.05
# epoch 78 training f1: 0.3698
#
# epoch 78 validation f1: 0.2450
#
# training time: 5.18
# epoch 79 training f1: 0.3564
#
# epoch 79 validation f1: 0.2483
#
# training time: 4.95
# epoch 80 training f1: 0.3727
#
# epoch 80 validation f1: 0.2457
#
# training time: 5.07
# epoch 81 training f1: 0.3620
#
# epoch 81 validation f1: 0.2523
#
# training time: 5.04
# epoch 82 training f1: 0.3845
#
# epoch 82 validation f1: 0.2598
#
# training time: 4.93
# epoch 83 training f1: 0.3911
#
# epoch 83 validation f1: 0.2604
#
# training time: 5.20
# epoch 84 training f1: 0.3960
#
# epoch 84 validation f1: 0.2558
#
# training time: 5.06
# epoch 85 training f1: 0.3964
#
# epoch 85 validation f1: 0.2565
#
# training time: 5.02
# epoch 86 training f1: 0.4038
#
# epoch 86 validation f1: 0.2593
#
# training time: 5.20
# epoch 87 training f1: 0.4121
#
# epoch 87 validation f1: 0.2695
#
# training time: 5.12
# epoch 88 training f1: 0.4132
#
# epoch 88 validation f1: 0.2633
#
# training time: 5.17
# epoch 89 training f1: 0.4171
#
# epoch 89 validation f1: 0.2454
#
# training time: 4.97
# epoch 90 training f1: 0.4363
#
# epoch 90 validation f1: 0.2665
#
# training time: 5.22
# epoch 91 training f1: 0.4474
#
# epoch 91 validation f1: 0.2668
#
# training time: 5.05
# epoch 92 training f1: 0.4581
#
# epoch 92 validation f1: 0.2608
#
# training time: 5.02
# epoch 93 training f1: 0.4482
#
# epoch 93 validation f1: 0.2545
#
# training time: 5.16
# epoch 94 training f1: 0.4505
#
# epoch 94 validation f1: 0.2677
#
# training time: 5.04
# epoch 95 training f1: 0.4535
#
# epoch 95 validation f1: 0.2653
#
# training time: 5.20
# epoch 96 training f1: 0.4641
#
# epoch 96 validation f1: 0.2639
#
# training time: 5.03
# epoch 97 training f1: 0.4573
#
# epoch 97 validation f1: 0.2659
#
# training time: 5.04
# epoch 98 training f1: 0.4838
#
# epoch 98 validation f1: 0.2680
#
# training time: 5.19
# epoch 99 training f1: 0.4719
#
# epoch 99 validation f1: 0.2651
#
# training time: 5.09
# epoch 100 training f1: 0.4749
#
# epoch 100 validation f1: 0.2561
#
# training time: 5.18
# epoch 101 training f1: 0.4743
#
# epoch 101 validation f1: 0.2621
#
# training time: 5.03
# epoch 102 training f1: 0.4764
#
# epoch 102 validation f1: 0.2699
#
# training time: 5.04
# epoch 103 training f1: 0.5114
#
# epoch 103 validation f1: 0.2584
#
# training time: 5.05
# epoch 104 training f1: 0.5052
#
# epoch 104 validation f1: 0.2547
#
# training time: 5.01
# epoch 105 training f1: 0.5068
#
# epoch 105 validation f1: 0.2659
#
# training time: 5.14
# epoch 106 training f1: 0.5039
#
# epoch 106 validation f1: 0.2681
#
# training time: 4.99
# epoch 107 training f1: 0.5125
#
# epoch 107 validation f1: 0.2741
#
# training time: 5.17
# epoch 108 training f1: 0.5250
#
# epoch 108 validation f1: 0.2696
#
# training time: 5.00
# epoch 109 training f1: 0.5306
#
# epoch 109 validation f1: 0.2635
#
# training time: 4.96
# epoch 110 training f1: 0.5187
#
# epoch 110 validation f1: 0.2612
#
# training time: 5.15
# epoch 111 training f1: 0.5460
#
# epoch 111 validation f1: 0.2653
#
# training time: 5.00
# epoch 112 training f1: 0.5719
#
# epoch 112 validation f1: 0.2695
#
# training time: 5.20
# epoch 113 training f1: 0.5491
#
# epoch 113 validation f1: 0.2767
#
# training time: 5.02
# epoch 114 training f1: 0.5659
#
# epoch 114 validation f1: 0.2604
#
# training time: 5.02
# epoch 115 training f1: 0.5510
#
# epoch 115 validation f1: 0.2724
#
# training time: 4.95
# epoch 116 training f1: 0.5690
#
# epoch 116 validation f1: 0.2733
#
# training time: 4.97
# epoch 117 training f1: 0.5717
#
# epoch 117 validation f1: 0.2714
#
# training time: 5.20
# epoch 118 training f1: 0.5697
#
# epoch 118 validation f1: 0.2720
#
# training time: 5.41
# epoch 119 training f1: 0.5730
#
# epoch 119 validation f1: 0.2783
#
# training time: 5.16
# epoch 120 training f1: 0.5740
#
# epoch 120 validation f1: 0.2864
#
# training time: 5.05
# epoch 121 training f1: 0.5751
#
# epoch 121 validation f1: 0.2638
#
# training time: 4.97
# epoch 122 training f1: 0.5893
#
# epoch 122 validation f1: 0.2584
#
# training time: 5.16
# epoch 123 training f1: 0.5986
#
# epoch 123 validation f1: 0.2670
#
# training time: 4.95
# epoch 124 training f1: 0.6084
#
# epoch 124 validation f1: 0.2670
#
# training time: 5.10
# epoch 125 training f1: 0.6152
#
# epoch 125 validation f1: 0.2659
#
# training time: 4.97
# epoch 126 training f1: 0.6041
#
# epoch 126 validation f1: 0.2748
#
# training time: 4.98
# epoch 127 training f1: 0.6172
#
# epoch 127 validation f1: 0.2770
#
# training time: 5.01
# epoch 128 training f1: 0.6024
#
# epoch 128 validation f1: 0.2802
#
# training time: 5.00
# epoch 129 training f1: 0.6114
#
# epoch 129 validation f1: 0.2811
#
# training time: 5.12
# epoch 130 training f1: 0.6169
#
# epoch 130 validation f1: 0.2837
#
# training time: 4.97
# epoch 131 training f1: 0.6360
#
# epoch 131 validation f1: 0.2727
#
# training time: 4.99
# epoch 132 training f1: 0.6327
#
# epoch 132 validation f1: 0.2729
#
# training time: 5.02
# epoch 133 training f1: 0.6368
#
# epoch 133 validation f1: 0.2874
#
# training time: 4.92
# epoch 134 training f1: 0.6498
#
# epoch 134 validation f1: 0.2816
#
# training time: 5.10
# epoch 135 training f1: 0.6590
#
# epoch 135 validation f1: 0.2840
#
# training time: 4.97
# epoch 136 training f1: 0.6679
#
# epoch 136 validation f1: 0.2638
#
# training time: 5.04
# epoch 137 training f1: 0.6475
#
# epoch 137 validation f1: 0.2875
#
# training time: 4.99
# epoch 138 training f1: 0.6574
#
# epoch 138 validation f1: 0.2770
#
# training time: 4.98
# epoch 139 training f1: 0.6410
#
# epoch 139 validation f1: 0.2741
#
# training time: 5.12
# epoch 140 training f1: 0.6647
#
# epoch 140 validation f1: 0.2930
#
# training time: 4.96
# epoch 141 training f1: 0.6677
#
# epoch 141 validation f1: 0.2857
#
# training time: 5.08
# epoch 142 training f1: 0.6739
#
# epoch 142 validation f1: 0.2792
#
# training time: 5.02
# epoch 143 training f1: 0.6649
#
# epoch 143 validation f1: 0.2854
#
# training time: 5.01
# epoch 144 training f1: 0.6718
#
# epoch 144 validation f1: 0.2857
#
# training time: 4.95
# epoch 145 training f1: 0.6697
#
# epoch 145 validation f1: 0.2961
#
# training time: 4.93
# epoch 146 training f1: 0.6921
#
# epoch 146 validation f1: 0.2910
#
# training time: 5.13
# epoch 147 training f1: 0.6907
#
# epoch 147 validation f1: 0.2964
#
# training time: 4.96
# epoch 148 training f1: 0.6899
#
# epoch 148 validation f1: 0.2857
#
# training time: 5.13
# epoch 149 training f1: 0.6989
#
# epoch 149 validation f1: 0.2905
#
# training time: 5.05
# epoch 150 training f1: 0.7013
#
# epoch 150 validation f1: 0.2878
#
# training time: 4.97
# epoch 151 training f1: 0.6944
#
# epoch 151 validation f1: 0.2905
#
# training time: 4.90
# epoch 152 training f1: 0.6992
#
# epoch 152 validation f1: 0.2938
#
# training time: 4.97
# epoch 153 training f1: 0.7137
#
# epoch 153 validation f1: 0.2978
#
# training time: 5.18
# epoch 154 training f1: 0.6831
#
# epoch 154 validation f1: 0.2974
#
# training time: 5.06
# epoch 155 training f1: 0.7173
#
# epoch 155 validation f1: 0.2787
#
# training time: 4.93
# epoch 156 training f1: 0.7237
#
# epoch 156 validation f1: 0.2826
#
# training time: 4.92
# epoch 157 training f1: 0.7221
#
# epoch 157 validation f1: 0.2878
#
# training time: 4.94
# epoch 158 training f1: 0.7222
#
# epoch 158 validation f1: 0.2864
#
# training time: 5.11
# epoch 159 training f1: 0.7169
#
# epoch 159 validation f1: 0.2832
#
# training time: 4.93
# epoch 160 training f1: 0.7238
#
# epoch 160 validation f1: 0.2808
#
# training time: 4.96
# epoch 161 training f1: 0.7141
#
# epoch 161 validation f1: 0.2969
#
# training time: 4.95
# epoch 162 training f1: 0.7196
#
# epoch 162 validation f1: 0.2945
#
# training time: 4.89
# epoch 163 training f1: 0.7087
#
# epoch 163 validation f1: 0.2998
#
# training time: 5.09
# epoch 164 training f1: 0.7145
#
# epoch 164 validation f1: 0.2820
#
# training time: 5.01
# epoch 165 training f1: 0.7506
#
# epoch 165 validation f1: 0.2960
#
# training time: 4.97
# epoch 166 training f1: 0.7268
#
# epoch 166 validation f1: 0.2910
#
# training time: 4.96
# epoch 167 training f1: 0.7316
#
# epoch 167 validation f1: 0.2827
#
# training time: 4.97
# epoch 168 training f1: 0.7415
#
# epoch 168 validation f1: 0.3077
#
# training time: 5.06
# epoch 169 training f1: 0.7490
#
# epoch 169 validation f1: 0.2846
#
# training time: 5.02
# epoch 170 training f1: 0.7324
#
# epoch 170 validation f1: 0.3061
#
# training time: 4.99
# epoch 171 training f1: 0.7507
#
# epoch 171 validation f1: 0.3012
#
# training time: 5.00
# epoch 172 training f1: 0.7590
#
# epoch 172 validation f1: 0.2958
#
# training time: 4.99
# epoch 173 training f1: 0.7724
#
# epoch 173 validation f1: 0.3056
#
# training time: 5.04
# epoch 174 training f1: 0.7536
#
# epoch 174 validation f1: 0.3004
#
# training time: 4.97
# epoch 175 training f1: 0.7563
#
# epoch 175 validation f1: 0.3030
#
# training time: 4.98
# epoch 176 training f1: 0.7710
#
# epoch 176 validation f1: 0.2844
#
# training time: 4.92
# epoch 177 training f1: 0.7485
#
# epoch 177 validation f1: 0.3049
#
# training time: 4.92
# epoch 178 training f1: 0.7637
#
# epoch 178 validation f1: 0.3044
#
# training time: 5.04
# epoch 179 training f1: 0.7765
#
# epoch 179 validation f1: 0.3042
#
# training time: 4.98
# epoch 180 training f1: 0.7698
#
# epoch 180 validation f1: 0.3017
#
# training time: 5.06
# epoch 181 training f1: 0.7777
#
# epoch 181 validation f1: 0.3031
#
# training time: 4.96
# epoch 182 training f1: 0.7849
#
# epoch 182 validation f1: 0.2933
#
# training time: 4.91
# epoch 183 training f1: 0.8007
#
# epoch 183 validation f1: 0.3119
#
# training time: 4.91
# epoch 184 training f1: 0.7836
#
# epoch 184 validation f1: 0.2864
#
# training time: 4.96
# epoch 185 training f1: 0.7702
#
# epoch 185 validation f1: 0.2917
#
# training time: 5.08
# epoch 186 training f1: 0.7680
#
# epoch 186 validation f1: 0.2961
#
# training time: 4.91
# epoch 187 training f1: 0.7921
#
# epoch 187 validation f1: 0.3077
#
# training time: 4.92
# epoch 188 training f1: 0.7720
#
# epoch 188 validation f1: 0.2925
#
# training time: 4.93
# epoch 189 training f1: 0.7800
#
# epoch 189 validation f1: 0.3046
#
# training time: 4.97
# epoch 190 training f1: 0.7851
#
# epoch 190 validation f1: 0.2974
#
# training time: 5.10
# epoch 191 training f1: 0.8083
#
# epoch 191 validation f1: 0.3038
#
# training time: 5.00
# epoch 192 training f1: 0.7971
#
# epoch 192 validation f1: 0.2926
#
# training time: 5.07
# epoch 193 training f1: 0.7989
#
# epoch 193 validation f1: 0.3030
#
# training time: 4.97
# epoch 194 training f1: 0.8027
#
# epoch 194 validation f1: 0.3046
#
# training time: 4.96
# epoch 195 training f1: 0.7971
#
# epoch 195 validation f1: 0.3081
#
# training time: 5.05
# epoch 196 training f1: 0.8000
#
# epoch 196 validation f1: 0.3110
#
# training time: 4.94
# epoch 197 training f1: 0.8125
#
# epoch 197 validation f1: 0.3018
#
# training time: 5.07
# epoch 198 training f1: 0.7984
#
# epoch 198 validation f1: 0.2919
#
# training time: 4.99
# epoch 199 training f1: 0.8020
#
# epoch 199 validation f1: 0.3053
#
# training time: 4.91
# epoch 200 training f1: 0.8106
#
# epoch 200 validation f1: 0.3093
#
# training time: 4.96
# epoch 201 training f1: 0.8230
#
# epoch 201 validation f1: 0.3101
#
# training time: 4.97
# epoch 202 training f1: 0.8087
#
# epoch 202 validation f1: 0.3110
#
# training time: 5.07
# epoch 203 training f1: 0.8042
#
# epoch 203 validation f1: 0.2963
# INFO:tensorflow:Restoring parameters from /content/drive/MyDrive/Pubmed/SavedModels/BC2GM_tt_gru_crf_1600_0.ckpt
# 2022-04-28 06:26:17 tensorflow INFO: Restoring parameters from /content/drive/MyDrive/Pubmed/SavedModels/BC2GM_tt_gru_crf_1600_0.ckpt
# Before M1-M3 iteration, doc_len_holdout array: 8064
# Before M1-M3 iteration, X_train array: 205500
# Val size 2:  749
# iteration 1: adding 749 samples from holdout to train
# Printing X_train after adding from holdout (4859, 50)
# Printing y_train after adding from holdout (4859, 50)
# Printing doc_len_train after adding from holdout (4859,)
# Printing inverted val size:  7315
# Printing X_holdout after adding from holdout (7315, 50)
# Printing doc_len_holdout after adding from holdout (7315,)
# After M1-M3 iteration, doc_len_holdout array: 7315
# After M1-M3 iteration, X_train array: 242950
#
# y_pred_gru:  (7315, 50)
# scores gru:  (7315,)
#
# y_pred_rnn:  (7315, 50)
# scores_rnn:  (7315,)
# Before M2-M3 iteration, doc_len_holdout array: 7315
# Before M2-M3 iteration, X_train array: 242950
# Val size-3:  428
# iteration 1: adding 428 samples from holdout to train
# Printing X_train after adding from holdout (5287, 50)
# Printing y_train after adding from holdout (5287, 50)
# Printing doc_len_train after adding from holdout (5287,)
# Printing inverted val size:  6887
# Printing X_holdout after adding from holdout (6887, 50)
# Printing doc_len_holdout after adding from holdout (6887,)
# After M2-M3 iteration, doc_len_holdout array: 6887
# After M2-M3 iteration, X_train array: 264350
# Filter size for this iteration:  3687
#
# Test set evaluation for BiLSTM CRF iteration 1 results on 1600 samples
# precision: 0.26167566298990846
# recall: 0.1820408163265306
# f1: 0.2147121124590795
#
#
# Test set evaluation for BiRNN CRF iteration 1 results on 1600 samples
# precision: 0.28086729572375024
# recall: 0.22840816326530614
# f1: 0.25193589050963444
#
#
# Test set evaluation for BiGRU CRF iteration 1 results on 1600 samples
# precision: 0.3285606631499623
# recall: 0.284734693877551
# f1: 0.30508178080993614
#
# train size: 5287
# Entered BiLSTM-CRF. Training network on 5287 documents, validation on 400 documents
#
# training time: 7.21
# epoch 1 training f1: 0.0042
#
# epoch 1 validation f1: 0.0105
#
# training time: 6.28
# epoch 2 training f1: 0.0049
#
# epoch 2 validation f1: 0.0038
#
# training time: 6.56
# epoch 3 training f1: 0.0047
#
# epoch 3 validation f1: 0.0038
#
# training time: 6.27
# epoch 4 training f1: 0.0056
#
# epoch 4 validation f1: 0.0038
#
# training time: 6.46
# epoch 5 training f1: 0.0112
#
# epoch 5 validation f1: 0.0112
#
# training time: 6.32
# epoch 6 training f1: 0.0201
#
# epoch 6 validation f1: 0.0146
#
# training time: 6.51
# epoch 7 training f1: 0.0312
#
# epoch 7 validation f1: 0.0152
#
# training time: 6.40
# epoch 8 training f1: 0.0308
#
# epoch 8 validation f1: 0.0182
#
# training time: 6.51
# epoch 9 training f1: 0.0399
#
# epoch 9 validation f1: 0.0181
#
# training time: 6.44
# epoch 10 training f1: 0.0495
#
# epoch 10 validation f1: 0.0246
#
# training time: 6.52
# epoch 11 training f1: 0.0545
#
# epoch 11 validation f1: 0.0304
#
# training time: 6.41
# epoch 12 training f1: 0.0527
#
# epoch 12 validation f1: 0.0335
#
# training time: 6.45
# epoch 13 training f1: 0.0626
#
# epoch 13 validation f1: 0.0388
#
# training time: 6.41
# epoch 14 training f1: 0.0743
#
# epoch 14 validation f1: 0.0400
#
# training time: 6.33
# epoch 15 training f1: 0.0797
#
# epoch 15 validation f1: 0.0491
#
# training time: 6.37
# epoch 16 training f1: 0.1027
#
# epoch 16 validation f1: 0.0754
#
# training time: 6.38
# epoch 17 training f1: 0.1047
#
# epoch 17 validation f1: 0.0655
#
# training time: 6.39
# epoch 18 training f1: 0.1170
#
# epoch 18 validation f1: 0.0783
#
# training time: 6.36
# epoch 19 training f1: 0.1181
#
# epoch 19 validation f1: 0.0940
#
# training time: 6.54
# epoch 20 training f1: 0.1262
#
# epoch 20 validation f1: 0.0850
#
# training time: 6.31
# epoch 21 training f1: 0.1416
#
# epoch 21 validation f1: 0.1217
#
# training time: 6.48
# epoch 22 training f1: 0.1462
#
# epoch 22 validation f1: 0.1411
#
# training time: 6.33
# epoch 23 training f1: 0.1445
#
# epoch 23 validation f1: 0.1516
#
# training time: 6.46
# epoch 24 training f1: 0.1513
#
# epoch 24 validation f1: 0.1491
#
# training time: 6.40
# epoch 25 training f1: 0.1689
#
# epoch 25 validation f1: 0.1448
#
# training time: 6.45
# epoch 26 training f1: 0.1755
#
# epoch 26 validation f1: 0.1653
#
# training time: 6.30
# epoch 27 training f1: 0.1723
#
# epoch 27 validation f1: 0.1699
#
# training time: 6.43
# epoch 28 training f1: 0.1916
#
# epoch 28 validation f1: 0.1761
#
# training time: 6.44
# epoch 29 training f1: 0.1873
#
# epoch 29 validation f1: 0.1865
#
# training time: 6.58
# epoch 30 training f1: 0.2131
#
# epoch 30 validation f1: 0.1902
#
# training time: 6.31
# epoch 31 training f1: 0.2044
#
# epoch 31 validation f1: 0.1913
#
# training time: 6.49
# epoch 32 training f1: 0.2169
#
# epoch 32 validation f1: 0.1914
#
# training time: 6.38
# epoch 33 training f1: 0.2226
#
# epoch 33 validation f1: 0.2035
#
# training time: 6.36
# epoch 34 training f1: 0.2263
#
# epoch 34 validation f1: 0.2008
#
# training time: 6.28
# epoch 35 training f1: 0.2362
#
# epoch 35 validation f1: 0.1948
#
# training time: 6.28
# epoch 36 training f1: 0.2407
#
# ...
#
# training time: 11.90
# epoch 33 training f1: 0.3274
#
# epoch 33 validation f1: 0.1855
#
# training time: 12.02
# epoch 34 training f1: 0.3426
#
# epoch 34 validation f1: 0.1804
#
# training time: 12.18
# epoch 35 training f1: 0.3374
#
# epoch 35 validation f1: 0.1887
#
# training time: 11.95
# epoch 36 training f1: 0.3446
#
# epoch 36 validation f1: 0.1863
#
# training time: 11.85
# epoch 37 training f1: 0.3460
#
# epoch 37 validation f1: 0.2132
#
# training time: 11.74
# epoch 38 training f1: 0.3378
#
# epoch 38 validation f1: 0.2256
#
# training time: 12.31
# epoch 39 training f1: 0.3713
#
# epoch 39 validation f1: 0.2076
#
# training time: 11.93
# epoch 40 training f1: 0.3687
#
# epoch 40 validation f1: 0.1864
#
# training time: 11.94
# epoch 41 training f1: 0.3740
#
# epoch 41 validation f1: 0.2175
#
# training time: 12.19
# epoch 42 training f1: 0.3781
#
# epoch 42 validation f1: 0.2293
#
# training time: 11.84
# epoch 43 training f1: 0.3828
#
# epoch 43 validation f1: 0.2034
#
# training time: 11.98
# epoch 44 training f1: 0.3970
#
# epoch 44 validation f1: 0.2000
#
# training time: 12.05
# epoch 45 training f1: 0.3805
#
# epoch 45 validation f1: 0.2012
#
# training time: 12.04
# epoch 46 training f1: 0.3990
#
# epoch 46 validation f1: 0.2209
#
# training time: 12.10
# epoch 47 training f1: 0.4082
#
# epoch 47 validation f1: 0.2110
#
# training time: 11.83
# epoch 48 training f1: 0.4151
#
# epoch 48 validation f1: 0.1892
#
# training time: 11.78
# epoch 49 training f1: 0.4180
#
# epoch 49 validation f1: 0.2195
#
# training time: 12.11
# epoch 50 training f1: 0.4394
#
# epoch 50 validation f1: 0.2109
#
# training time: 11.94
# epoch 51 training f1: 0.4311
#
# epoch 51 validation f1: 0.2273
#
# training time: 12.25
# epoch 52 training f1: 0.4357
#
# epoch 52 validation f1: 0.2038
#
# training time: 11.83
# epoch 53 training f1: 0.4470
#
# epoch 53 validation f1: 0.2105
#
# training time: 11.85
# epoch 54 training f1: 0.4527
#
# epoch 54 validation f1: 0.2060
#
# training time: 12.03
# epoch 55 training f1: 0.4394
#
# epoch 55 validation f1: 0.2072
#
# training time: 11.93
# epoch 56 training f1: 0.4537
#
# epoch 56 validation f1: 0.2283
#
# training time: 12.04
# epoch 57 training f1: 0.4556
#
# epoch 57 validation f1: 0.2171
#
# training time: 11.89
# epoch 58 training f1: 0.4678
#
# epoch 58 validation f1: 0.2212
#
# training time: 12.25
# epoch 59 training f1: 0.4785
#
# epoch 59 validation f1: 0.2444
#
# training time: 11.92
# epoch 60 training f1: 0.4855
#
# epoch 60 validation f1: 0.2398
#
# training time: 12.16
# epoch 61 training f1: 0.4845
#
# epoch 61 validation f1: 0.2159
#
# training time: 11.87
# epoch 62 training f1: 0.4877
#
# epoch 62 validation f1: 0.2356
#
# training time: 11.79
# epoch 63 training f1: 0.4931
#
# epoch 63 validation f1: 0.2417
#
# training time: 12.04
# epoch 64 training f1: 0.4956
#
# epoch 64 validation f1: 0.2311
#
# training time: 11.98
# epoch 65 training f1: 0.5080
#
# epoch 65 validation f1: 0.2271
#
# training time: 12.22
# epoch 66 training f1: 0.5216
#
# epoch 66 validation f1: 0.2202
#
# training time: 11.95
# epoch 67 training f1: 0.5239
#
# epoch 67 validation f1: 0.2315
#
# training time: 11.75
# epoch 68 training f1: 0.5193
#
# epoch 68 validation f1: 0.2141
#
# training time: 12.12
# epoch 69 training f1: 0.5310
#
# epoch 69 validation f1: 0.2331
#
# training time: 11.95
# epoch 70 training f1: 0.5299
#
# epoch 70 validation f1: 0.2440
#
# training time: 11.86
# epoch 71 training f1: 0.5292
#
# epoch 71 validation f1: 0.2258
#
# training time: 11.98
# epoch 72 training f1: 0.5359
#
# epoch 72 validation f1: 0.2294
#
# training time: 11.75
# epoch 73 training f1: 0.5591
#
# epoch 73 validation f1: 0.2212
#
# training time: 12.06
# epoch 74 training f1: 0.5547
#
# epoch 74 validation f1: 0.2272
#
# training time: 12.07
# epoch 75 training f1: 0.5545
#
# epoch 75 validation f1: 0.2278
#
# training time: 11.85
# epoch 76 training f1: 0.5732
#
# epoch 76 validation f1: 0.2296
#
# training time: 12.17
# epoch 77 training f1: 0.5752
#
# epoch 77 validation f1: 0.2278
#
# training time: 11.74
# epoch 78 training f1: 0.5697
#
# epoch 78 validation f1: 0.2377
#
# training time: 12.10
# epoch 79 training f1: 0.5724
#
# epoch 79 validation f1: 0.2378
# INFO:tensorflow:Restoring parameters from /content/drive/MyDrive/Pubmed/SavedModels/BC2GM_tt_gru_crf_1600_23.ckpt
# 2022-04-29 05:28:59 tensorflow INFO: Restoring parameters from /content/drive/MyDrive/Pubmed/SavedModels/BC2GM_tt_gru_crf_1600_23.ckpt
# Before M1-M3 iteration, doc_len_holdout array: 2765
# Before M1-M3 iteration, X_train array: 470450
# Val size 2:  4
# iteration 24: adding 4 samples from holdout to train
# Printing X_train after adding from holdout (9413, 50)
# Printing y_train after adding from holdout (9413, 50)
# Printing doc_len_train after adding from holdout (9413,)
# Printing inverted val size:  2761
# Printing X_holdout after adding from holdout (2761, 50)
# Printing doc_len_holdout after adding from holdout (2761,)
# After M1-M3 iteration, doc_len_holdout array: 2761
# After M1-M3 iteration, X_train array: 470650
#
# y_pred_gru:  (2761, 50)
# scores gru:  (2761,)
#
# y_pred_rnn:  (2761, 50)
# scores_rnn:  (2761,)
# Before M2-M3 iteration, doc_len_holdout array: 2761
# Before M2-M3 iteration, X_train array: 470650
# Val size-3:  2
# iteration 24: adding 2 samples from holdout to train
# Printing X_train after adding from holdout (9415, 50)
# Printing y_train after adding from holdout (9415, 50)
# Printing doc_len_train after adding from holdout (9415,)
# Printing inverted val size:  2759
# Printing X_holdout after adding from holdout (2759, 50)
# Printing doc_len_holdout after adding from holdout (2759,)
# After M2-M3 iteration, doc_len_holdout array: 2759
# After M2-M3 iteration, X_train array: 470750
# Filter size for this iteration:  10
#
# Test set evaluation for BiLSTM CRF iteration 24 results on 9405 samples
# precision: 0.31989247311827956
# recall: 0.15542857142857142
# f1: 0.20920777936490495
#
#
# Test set evaluation for BiRNN CRF iteration 24 results on 9405 samples
# precision: 0.3731700029877502
# recall: 0.20391836734693877
# f1: 0.26372466216216217
#
#
# Test set evaluation for BiGRU CRF iteration 24 results on 9405 samples
# precision: 0.313441483198146
# recall: 0.1766530612244898
# f1: 0.2259580244335387
#
# train size: 9415
# Entered BiLSTM-CRF. Training network on 9415 documents, validation on 400 documents
#
# training time: 12.42
# epoch 1 training f1: 0.0060
#
# epoch 1 validation f1: 0.0000
#
# training time: 11.82
# epoch 2 training f1: 0.0013
#
# epoch 2 validation f1: 0.0000
#
# training time: 11.97
# epoch 3 training f1: 0.0006
#
# epoch 3 validation f1: 0.0041
#
# training time: 11.99
# epoch 4 training f1: 0.0069
#
# epoch 4 validation f1: 0.0080
#
# training time: 11.91
# epoch 5 training f1: 0.0278
#
# epoch 5 validation f1: 0.0232
#
# training time: 12.12
# epoch 6 training f1: 0.0408
#
# epoch 6 validation f1: 0.0331
#
# training time: 11.85
# epoch 7 training f1: 0.0541
#
# epoch 7 validation f1: 0.0427
#
# training time: 12.00
# epoch 8 training f1: 0.0798
#
# epoch 8 validation f1: 0.0490
#
# training time: 11.74
# epoch 9 training f1: 0.0953
#
# epoch 9 validation f1: 0.0620
#
# training time: 11.85
# epoch 10 training f1: 0.1192
#
# epoch 10 validation f1: 0.0797
#
# training time: 12.05
# epoch 11 training f1: 0.1422
#
# epoch 11 validation f1: 0.0712
#
# training time: 11.95
# epoch 12 training f1: 0.1530
#
# epoch 12 validation f1: 0.0908
#
# training time: 11.90
# epoch 13 training f1: 0.1660
#
# epoch 13 validation f1: 0.0781
#
# training time: 11.90
# epoch 14 training f1: 0.1795
#
# epoch 14 validation f1: 0.0980
#
# training time: 11.69
# epoch 15 training f1: 0.1852
#
# epoch 15 validation f1: 0.1094
#
# training time: 11.75
# epoch 16 training f1: 0.1913
#
# epoch 16 validation f1: 0.1116
#
# training time: 12.04
# epoch 17 training f1: 0.2082
#
# epoch 17 validation f1: 0.1206
#
# training time: 11.95
# epoch 18 training f1: 0.2157
#
# epoch 18 validation f1: 0.1186
#
# training time: 12.00
# epoch 19 training f1: 0.2294
#
# epoch 19 validation f1: 0.1266
#
# training time: 11.73
# epoch 20 training f1: 0.2293
#
# epoch 20 validation f1: 0.1250
#
# training time: 11.87
# epoch 21 training f1: 0.2432
#
# epoch 21 validation f1: 0.1242
#
# training time: 11.91
# epoch 22 training f1: 0.2358
#
# epoch 22 validation f1: 0.1370
#
# training time: 12.04
# epoch 23 training f1: 0.2434
#
# epoch 23 validation f1: 0.1389
#
# training time: 12.12
# epoch 24 training f1: 0.2500
#
# epoch 24 validation f1: 0.1501
#
# training time: 11.75
# epoch 25 training f1: 0.2618
#
# epoch 25 validation f1: 0.1515
#
# training time: 11.77
# epoch 26 training f1: 0.2622
#
# epoch 26 validation f1: 0.1426
#
# training time: 11.87
# epoch 27 training f1: 0.2727
#
# epoch 27 validation f1: 0.1455
#
# training time: 11.85
# epoch 28 training f1: 0.2886
#
# epoch 28 validation f1: 0.1496
#
# training time: 12.02
# epoch 29 training f1: 0.2789
#
# epoch 29 validation f1: 0.1575
#
# training time: 11.93
# epoch 30 training f1: 0.2906
#
# epoch 30 validation f1: 0.1491
#
# training time: 11.90
# epoch 31 training f1: 0.2985
#
# epoch 31 validation f1: 0.1458
#
# training time: 11.89
# epoch 32 training f1: 0.3004
#
# epoch 32 validation f1: 0.1767
#
# training time: 11.79
# epoch 33 training f1: 0.3054
#
# epoch 33 validation f1: 0.1618
#
# training time: 11.88
# epoch 34 training f1: 0.3230
#
# epoch 34 validation f1: 0.1494
#
# training time: 12.06
# epoch 35 training f1: 0.3264
#
# epoch 35 validation f1: 0.1607
#
# training time: 11.80
# epoch 36 training f1: 0.3277
#
# epoch 36 validation f1: 0.1771
#
# training time: 12.05
# epoch 37 training f1: 0.3258
#
# epoch 37 validation f1: 0.1672
#
# training time: 11.87
# epoch 38 training f1: 0.3474
#
# epoch 38 validation f1: 0.1680
#
# training time: 12.02
# epoch 39 training f1: 0.3442
#
# epoch 39 validation f1: 0.1609
#
# training time: 11.88
# epoch 40 training f1: 0.3471
#
# epoch 40 validation f1: 0.1685
#
# training time: 11.82
# epoch 41 training f1: 0.3570
#
# epoch 41 validation f1: 0.1627
#
# training time: 12.08
# epoch 42 training f1: 0.3651
#
# epoch 42 validation f1: 0.1674
#
# training time: 11.77
# epoch 43 training f1: 0.3577
#
# epoch 43 validation f1: 0.1690
#
# training time: 11.80
# epoch 44 training f1: 0.3727
#
# epoch 44 validation f1: 0.1646
#
# training time: 11.91
# epoch 45 training f1: 0.3807
#
# epoch 45 validation f1: 0.1848
#
# training time: 11.96
# epoch 46 training f1: 0.3804
#
# epoch 46 validation f1: 0.2030
#
# training time: 11.90
# epoch 47 training f1: 0.3926
#
# epoch 47 validation f1: 0.1790
#
# training time: 12.07
# epoch 48 training f1: 0.3964
#
# epoch 48 validation f1: 0.1936
#
# training time: 11.61
# epoch 49 training f1: 0.4018
#
# epoch 49 validation f1: 0.1855
#
# training time: 11.83
# epoch 50 training f1: 0.4031
#
# epoch 50 validation f1: 0.1982
#
# training time: 11.77
# epoch 51 training f1: 0.4115
#
# epoch 51 validation f1: 0.2033
#
# training time: 11.89
# epoch 52 training f1: 0.4246
#
# epoch 52 validation f1: 0.2057
#
# training time: 12.03
# epoch 53 training f1: 0.4223
#
# epoch 53 validation f1: 0.2019
#
# training time: 11.90
# epoch 54 training f1: 0.4253
#
# epoch 54 validation f1: 0.2009
#
# training time: 11.86
# epoch 55 training f1: 0.4394
#
# epoch 55 validation f1: 0.1953
#
# training time: 11.92
# epoch 56 training f1: 0.4369
#
# epoch 56 validation f1: 0.1969
#
# training time: 11.77
# epoch 57 training f1: 0.4457
#
# epoch 57 validation f1: 0.1994
#
# training time: 11.84
# epoch 58 training f1: 0.4631
#
# epoch 58 validation f1: 0.2095
#
# training time: 12.29
# epoch 59 training f1: 0.4679
#
# epoch 59 validation f1: 0.2016
#
# training time: 11.86
# epoch 60 training f1: 0.4584
#
# epoch 60 validation f1: 0.1997
#
# training time: 12.13
# epoch 61 training f1: 0.4728
#
# epoch 61 validation f1: 0.2137
#
# training time: 11.88
# epoch 62 training f1: 0.4648
#
# epoch 62 validation f1: 0.1902
#
# training time: 11.68
# epoch 63 training f1: 0.4838
#
# epoch 63 validation f1: 0.2295
#
# training time: 12.16
# epoch 64 training f1: 0.4860
#
# epoch 64 validation f1: 0.2376
#
# training time: 11.98
# epoch 65 training f1: 0.4835
#
# epoch 65 validation f1: 0.2247
#
# training time: 11.87
# epoch 66 training f1: 0.5026
#
# epoch 66 validation f1: 0.1908
#
# training time: 12.00
# epoch 67 training f1: 0.4972
#
# epoch 67 validation f1: 0.2321
#
# training time: 11.94
# epoch 68 training f1: 0.5130
#
# epoch 68 validation f1: 0.2085
#
# training time: 11.65
# epoch 69 training f1: 0.5129
#
# epoch 69 validation f1: 0.2229
#
# training time: 12.14
# epoch 70 training f1: 0.5252
#
# epoch 70 validation f1: 0.2194
#
# training time: 11.91
# epoch 71 training f1: 0.5154
#
# epoch 71 validation f1: 0.2353
#
# training time: 12.17
# epoch 72 training f1: 0.5172
#
# epoch 72 validation f1: 0.2186
#
# training time: 11.89
# epoch 73 training f1: 0.5389
#
# epoch 73 validation f1: 0.2317
#
# training time: 11.92
# epoch 74 training f1: 0.5508
#
# epoch 74 validation f1: 0.2389
#
# training time: 11.88
# epoch 75 training f1: 0.5500
#
# epoch 75 validation f1: 0.2372
#
# training time: 11.80
# epoch 76 training f1: 0.5481
#
# epoch 76 validation f1: 0.2274
#
# training time: 11.85
# epoch 77 training f1: 0.5462
#
# epoch 77 validation f1: 0.2348
#
# training time: 12.14
# epoch 78 training f1: 0.5614
#
# epoch 78 validation f1: 0.2331
#
# training time: 12.01
# epoch 79 training f1: 0.5693
#
# epoch 79 validation f1: 0.1934
#
# training time: 12.14
# epoch 80 training f1: 0.5828
#
# epoch 80 validation f1: 0.2304
#
# training time: 11.68
# epoch 81 training f1: 0.5899
#
# epoch 81 validation f1: 0.2351
#
# training time: 11.65
# epoch 82 training f1: 0.5688
#
# epoch 82 validation f1: 0.2032
#
# training time: 12.22
# epoch 83 training f1: 0.5760
#
# epoch 83 validation f1: 0.2687
#
# training time: 12.06
# epoch 84 training f1: 0.6033
#
# epoch 84 validation f1: 0.2236
#
# training time: 11.87
# epoch 85 training f1: 0.5918
#
# epoch 85 validation f1: 0.2297
#
# training time: 11.86
# epoch 86 training f1: 0.6217
#
# epoch 86 validation f1: 0.2372
#
# training time: 11.74
# epoch 87 training f1: 0.5956
#
# epoch 87 validation f1: 0.2315
#
# training time: 11.78
# epoch 88 training f1: 0.6228
#
# epoch 88 validation f1: 0.2303
#
# training time: 12.09
# epoch 89 training f1: 0.6151
#
# epoch 89 validation f1: 0.2353
#
# training time: 11.91
# epoch 90 training f1: 0.6257
#
# epoch 90 validation f1: 0.2229
#
# training time: 12.13
# epoch 91 training f1: 0.6300
#
# epoch 91 validation f1: 0.2186
#
# training time: 11.93
# epoch 92 training f1: 0.6219
#
# epoch 92 validation f1: 0.2671
#
# training time: 11.83
# epoch 93 training f1: 0.6355
#
# epoch 93 validation f1: 0.2437
#
# training time: 11.91
# epoch 94 training f1: 0.6401
#
# epoch 94 validation f1: 0.2266
#
# training time: 11.65
# epoch 95 training f1: 0.6475
#
# epoch 95 validation f1: 0.2531
#
# training time: 12.11
# epoch 96 training f1: 0.6300
#
# epoch 96 validation f1: 0.2278
#
# training time: 12.13
# epoch 97 training f1: 0.6597
#
# epoch 97 validation f1: 0.2143
#
# training time: 11.94
# epoch 98 training f1: 0.6534
#
# epoch 98 validation f1: 0.2289
#
# training time: 12.03
# epoch 99 training f1: 0.6509
#
# epoch 99 validation f1: 0.2462
#
# training time: 11.71
# epoch 100 training f1: 0.6584
#
# epoch 100 validation f1: 0.2275
#
# training time: 11.81
# epoch 101 training f1: 0.6718
#
# epoch 101 validation f1: 0.2414
#
# training time: 12.07
# epoch 102 training f1: 0.6822
#
# epoch 102 validation f1: 0.2582
#
# training time: 11.93
# epoch 103 training f1: 0.6770
#
# epoch 103 validation f1: 0.2359
# Entered BiRNN-CRF. Training network on 9415 documents, validation on 400 documents
#
# training time: 10.36
# epoch 1 training f1: 0.0095
#
# epoch 1 validation f1: 0.0000
#
# training time: 9.84
# epoch 2 training f1: 0.0341
#
# epoch 2 validation f1: 0.0549
#
# training time: 9.73
# epoch 3 training f1: 0.0899
#
# epoch 3 validation f1: 0.0554
#
# training time: 9.95
# epoch 4 training f1: 0.1307
#
# epoch 4 validation f1: 0.0691
#
# training time: 9.69
# epoch 5 training f1: 0.1866
#
# epoch 5 validation f1: 0.1198
#
# training time: 9.93
# epoch 6 training f1: 0.2078
#
# epoch 6 validation f1: 0.1250
#
# training time: 10.11
# epoch 7 training f1: 0.2231
#
# epoch 7 validation f1: 0.1418
#
# training time: 9.93
# epoch 8 training f1: 0.2505
#
# epoch 8 validation f1: 0.1563
#
# training time: 10.07
# epoch 9 training f1: 0.2486
#
# epoch 9 validation f1: 0.1638
#
# training time: 9.96
# epoch 10 training f1: 0.2744
#
# epoch 10 validation f1: 0.1557
#
# training time: 9.77
# epoch 11 training f1: 0.2863
#
# epoch 11 validation f1: 0.1633
#
# training time: 10.00
# epoch 12 training f1: 0.3024
#
# epoch 12 validation f1: 0.1670
#
# training time: 9.93
# epoch 13 training f1: 0.3019
#
# epoch 13 validation f1: 0.1834
#
# training time: 9.81
# epoch 14 training f1: 0.3039
#
# epoch 14 validation f1: 0.1837
#
# training time: 10.21
# epoch 15 training f1: 0.3125
#
# epoch 15 validation f1: 0.1849
#
# training time: 9.68
# epoch 16 training f1: 0.3230
#
# epoch 16 validation f1: 0.1928
#
# training time: 10.03
# epoch 17 training f1: 0.3213
#
# epoch 17 validation f1: 0.1616

# %% [markdown]
# Finetuning the pretrained model on obtained training data

# %%
batch_size_as = 128
patience_as = 15

# %%
for dataset in datasets:

    # iterate over each data size setting
    for data_size in data_sizes:

        print('Training in the dataset loop',dataset,data_size)
        
        # load training data
        X_train = np.load("/content/drive/MyDrive/Pubmed/Asymmetric/%s_X_train_%i.npy" % (dataset,data_size)).astype(np.int16)
        y_train = np.load("/content/drive/MyDrive/Pubmed/Asymmetric/%s_y_train_%i.npy" % (dataset,data_size)).astype(np.int16)
        max_len = 50
        num_classes = np.max(y_train) + 1
      
        with open('/content/drive/MyDrive/Pubmed/Asymmetric/%s_senlens_%i.pkl' % (dataset,data_size),'rb') as f:
            doc_len_train = pickle.load(f)
        doc_len_train = [l if l <=max_len else max_len for l in doc_len_train]

        # load training data
        X_val = np.load("/content/drive/MyDrive/Pubmed/Asymmetric/%s_X_val_%i.npy" % (dataset,data_size)).astype(np.int16)
        y_val = np.load("/content/drive/MyDrive/Pubmed/Asymmetric/%s_y_val_%i.npy" % (dataset,data_size)).astype(np.int16)
       
        with open('/content/drive/MyDrive/Pubmed/Asymmetric/%s_senlens_val_%i.pkl' % (dataset,data_size),'rb') as f:
            doc_len_val = pickle.load(f)
        doc_len_val = [l if l <=max_len else max_len for l in doc_len_val]
        
        # load conversion dictionaries
        label2idx = {'O':0, 'B':1, 'I': 2}
        idx2label = {0:'O',1:'B-ENT',2:'I-ENT'}
            
        # load test data
        X_test = np.load('/content/drive/MyDrive/Pubmed/%s_X_test.npy' % dataset).astype(np.int16)
        y_test = np.load('/content/drive/MyDrive/Pubmed/%s_y_test.npy' % dataset).astype(np.int16)
        with open('/content/drive/MyDrive/Pubmed/%s_senlens_test.pkl' % dataset,'rb') as f:
            doc_len_test = pickle.load(f)
        doc_len_test = [l if l <=max_len else max_len for l in doc_len_test]
        y_true = []
        for y_true_,l in zip(y_test,doc_len_test):
            y = [idx2label[l] for l in y_true_[:l]]
            y_true.append(y)
        y_true_val = []
        for y_true_,l in zip(y_val,doc_len_val):
            y = [idx2label[l] for l in y_true_[:l]]
            y_true_val.append(y)
        
        tf.reset_default_graph()
        model = lstm_crf(vocab,num_classes,max_len)
        
        # Here load the pretrained model and train it on the new training set obtained after semi-supervised learning
        model.load('/content/drive/MyDrive/Pubmed/PretrainModel/lstm_crf_%s.ckpt' % pretrain_dataset)

        model.train(X_train,y_train,doc_len_train,
                    batch_size=batch_size_as,patience=patience_as,
                    validation_data=(X_val,y_val,doc_len_val),
                    savebest=True,filepath='/content/drive/MyDrive/Pubmed/FinetuneAsymmetric/%s_finetune_%s_%i.ckpt' % (dataset,pretrain_dataset,data_size))
        
        # Finally evaluate on test set
        model.load('/content/drive/MyDrive/Pubmed/FinetuneAsymmetric/%s_finetune_%s_%i.ckpt' % (dataset,pretrain_dataset,data_size))
        y_preds_,_,_ = model.predict(X_test,doc_len_test)
        y_pred = []
        for y_pred_,l in zip(y_preds_,doc_len_test):
            y = [idx2label[l] for l in y_pred_[:l]]
            y_pred.append(y)
        
        evaluator = Evaluator(y_true, y_pred, tags=['ENT'], loader="list")
        results, results_by_tag = evaluator.evaluate()
        
        exact_p = results['exact']['precision']
        exact_r = results['exact']['recall']
        exact_f = results['exact']['f1']
        partial_p = results['partial']['precision']
        partial_r = results['partial']['recall']
        partial_f = results['partial']['f1']
    
        print(dataset, data_size)
        print('exact p: %.4f' % exact_p)
        print('exact r: %.4f' % exact_r)
        print('exact f: %.4f' % exact_f)
        print('partial p: %.4f' % partial_p)
        print('partial r: %.4f' % partial_r)
        print('partial f: %.4f' % partial_f)
        print()
# Out:
# Training in the dataset loop s800 3000
# INFO:tensorflow:Restoring parameters from /content/drive/MyDrive/Pubmed/PretrainModel/lstm_crf_medmentions.ckpt
# 2022-05-01 10:50:45 tensorflow INFO: Restoring parameters from /content/drive/MyDrive/Pubmed/PretrainModel/lstm_crf_medmentions.ckpt
# training network on 4684 documents, validation on 600 documents
#
# training time: 11.66
# epoch 1 training f1: 0.0260
#
# epoch 1 validation f1: 0.0336
#
# training time: 10.95
# epoch 2 training f1: 0.0479
#
# epoch 2 validation f1: 0.1163
#
# training time: 10.84
# epoch 3 training f1: 0.0969
#
# epoch 3 validation f1: 0.1390
#
# training time: 10.84
# epoch 4 training f1: 0.1262
#
# epoch 4 validation f1: 0.1603
#
# training time: 10.74
# epoch 5 training f1: 0.1345
#
# epoch 5 validation f1: 0.1993
#
# training time: 10.88
# epoch 6 training f1: 0.1503
#
# epoch 6 validation f1: 0.1955
#
# training time: 11.13
# epoch 7 training f1: 0.1676
#
# epoch 7 validation f1: 0.2109
#
# training time: 10.96
# epoch 8 training f1: 0.1818
#
# epoch 8 validation f1: 0.2132
#
# training time: 10.96
# epoch 9 training f1: 0.1975
#
# epoch 9 validation f1: 0.2340
#
# training time: 11.14
# epoch 10 training f1: 0.2159
#
# epoch 10 validation f1: 0.2612
#
# training time: 10.99
# epoch 11 training f1: 0.2469
#
# epoch 11 validation f1: 0.2609
#
# training time: 10.80
# epoch 12 training f1: 0.2615
#
# epoch 12 validation f1: 0.2766
#
# training time: 10.83
# epoch 13 training f1: 0.2748
#
# epoch 13 validation f1: 0.3007
#
# training time: 10.82
# epoch 14 training f1: 0.3065
#
# epoch 14 validation f1: 0.3237
#
# training time: 10.97
# epoch 15 training f1: 0.3152
#
# epoch 15 validation f1: 0.3071
#
# training time: 10.80
# epoch 16 training f1: 0.3325
#
# epoch 16 validation f1: 0.3191
#
# training time: 10.99
# epoch 17 training f1: 0.3299
#
# epoch 17 validation f1: 0.3675
#
# training time: 10.81
# epoch 18 training f1: 0.3667
#
# epoch 18 validation f1: 0.3466
#
# training time: 10.91
# epoch 19 training f1: 0.3692
#
# epoch 19 validation f1: 0.3836
#
# training time: 10.79
# epoch 20 training f1: 0.3959
#
# epoch 20 validation f1: 0.3688
#
# training time: 11.01
# epoch 21 training f1: 0.3940
#
# epoch 21 validation f1: 0.3663
#
# training time: 10.83
# epoch 22 training f1: 0.4181
#
# epoch 22 validation f1: 0.3746
#
# training time: 10.91
# epoch 23 training f1: 0.4040
#
# epoch 23 validation f1: 0.3932
#
# training time: 10.87
# epoch 24 training f1: 0.4270
#
# epoch 24 validation f1: 0.3860
#
# training time: 10.92
# epoch 25 training f1: 0.4337
#
# epoch 25 validation f1: 0.3819
#
# training time: 11.03
# epoch 26 training f1: 0.4598
#
# epoch 26 validation f1: 0.3918
#
# training time: 10.81
# epoch 27 training f1: 0.4605
#
# epoch 27 validation f1: 0.3750
#
# training time: 10.94
# epoch 28 training f1: 0.4714
#
# epoch 28 validation f1: 0.3793
#
# training time: 10.87
# epoch 29 training f1: 0.4714
#
# epoch 29 validation f1: 0.3810
#
# training time: 10.92
# epoch 30 training f1: 0.4880
#
# epoch 30 validation f1: 0.3597
#
# training time: 10.92
# epoch 31 training f1: 0.4883
#
# epoch 31 validation f1: 0.3797
#
# training time: 11.01
# epoch 32 training f1: 0.4990
#
# epoch 32 validation f1: 0.3849
#
# training time: 10.93
# epoch 33 training f1: 0.5082
#
# epoch 33 validation f1: 0.3618
#
# training time: 10.95
# epoch 34 training f1: 0.5083
#
# epoch 34 validation f1: 0.3793
#
# training time: 10.79
# epoch 35 training f1: 0.5269
#
# epoch 35 validation f1: 0.3656
#
# training time: 10.86
# epoch 36 training f1: 0.5263
#
# epoch 36 validation f1: 0.3618
#
# training time: 10.86
# epoch 37 training f1: 0.5300
#
# epoch 37 validation f1: 0.3694
#
# training time: 10.95
# epoch 38 training f1: 0.5473
#
# epoch 38 validation f1: 0.3780
#
# training time: 11.18
# epoch 39 training f1: 0.5592
#
# epoch 39 validation f1: 0.3583
#
# training time: 10.91
# epoch 40 training f1: 0.5668
#
# epoch 40 validation f1: 0.3771
#
# training time: 11.04
# epoch 41 training f1: 0.5762
#
# epoch 41 validation f1: 0.3878
#
# training time: 10.94
# epoch 42 training f1: 0.5900
#
# epoch 42 validation f1: 0.3624
#
# training time: 11.11
# epoch 43 training f1: 0.5795
#
# epoch 43 validation f1: 0.3636
# INFO:tensorflow:Restoring parameters from /content/drive/MyDrive/Pubmed/FinetuneAsymmetric/s800_finetune_medmentions_3000.ckpt
# 2022-05-01 10:59:51 tensorflow INFO: Restoring parameters from /content/drive/MyDrive/Pubmed/FinetuneAsymmetric/s800_finetune_medmentions_3000.ckpt
# s800 3000
# exact p: 0.4538
# exact r: 0.2227
# exact f: 0.2987
# partial p: 0.6005
# partial r: 0.2947
# partial f: 0.3953
